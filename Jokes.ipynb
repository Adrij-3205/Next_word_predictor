# %%
import tensorflow as tf
from tensorflow.keras.preprocessing.text import Tokenizer
import numpy as np
import pandas as pd
import seaborn as sns

# %%
df=pd.read_csv("shortjokes.csv")

# %% [markdown]
# **Preprocessing**

# %%
df1=df
df1.head()
# Out:
#    ID                                               Joke
# 0   1  [me narrating a documentary about narrators] "...
# 1   2  Telling my daughter garlic is good for you. Go...
# 2   3  I've been going through a really rough period ...
# 3   4  If I could have dinner with anyone, dead or al...
# 4   5     Two guys walk into a bar. The third guy ducks.

# %%
df1.shape
# Out:
# (231657, 2)

# %%
desired_rows = 1000  #since the dataset is very large we take only 1000 random rows of it
sampled_df = df1.sample(n=desired_rows, random_state=42)

# %%
sampled_df.shape
# Out:
# (1000, 2)

# %%
joke_paragraph = '\n'.join(sampled_df['Joke'])#converting every joke in a paragraph based on new line

# %%
lines = joke_paragraph.split('\n')
for line in lines[:10]:
    print(line)
# Out:
# What do all battered women have in common? They don't listen.
# Who invented the North America? TEACHER: Sarah, go to the map and find North America. SARAH: Here it is. TEACHER: Correct. Now class, who discovered America?CLASS: Sarah!
# I feel like this election ended up being a good thing for Hilary Clinton. At least now she knows what it feels like to get fucked by the president.
# What do you call a pile of kittens? A Meowntain
# I feel bad for people named John Smith. They probably didn't get the gmail account they wanted.
# What would you have if your car's  motor was in flames? A fire engine.
# When accused by a woman a man's first instinct is to deny. We're not lying, we're just buying time to remember what you're talking about...
# I set my phone to airplane mode I lost it two weeks ago and everyone has a different opinion on what happened to it
# There's a thin line distinguishing "Heroes" from "Herpes"
# What did batman tell robin before they got in the car? Get in the car.

# %%
import nltk
from nltk.tokenize import word_tokenize

# %%
tokenizer = Tokenizer()

# %%
tokenizer.fit_on_texts([joke_paragraph])

# %%
len(tokenizer.word_index)
# Out:
# 3981

# %%
input_sequences = []
for sentence in joke_paragraph.split('\n'):
  tokenized_sentence = tokenizer.texts_to_sequences([sentence])[0]

  for i in range(1,len(tokenized_sentence)):
    input_sequences.append(tokenized_sentence[:i+1])

# %%
input_sequences
# Out:
# [[11, 13],
#  [11, 13, 46],
#  [11, 13, 46, 1529],
#  [11, 13, 46, 1529, 135],
#  [11, 13, 46, 1529, 135, 19],
#  [11, 13, 46, 1529, 135, 19, 6],
#  [11, 13, 46, 1529, 135, 19, 6, 267],
#  [11, 13, 46, 1529, 135, 19, 6, 267, 26],
#  [11, 13, 46, 1529, 135, 19, 6, 267, 26, 43],
#  [11, 13, 46, 1529, 135, 19, 6, 267, 26, 43, 507],
#  [49, 1530],
#  [49, 1530, 2],
#  [49, 1530, 2, 645],
#  [49, 1530, 2, 645, 268],
#  [49, 1530, 2, 645, 268, 303],
#  [49, 1530, 2, 645, 268, 303, 508],
#  [49, 1530, 2, 645, 268, 303, 508, 83],
#  [49, 1530, 2, 645, 268, 303, 508, 83, 4],
#  [49, 1530, 2, 645, 268, 303, 508, 83, 4, 2],
#  [49, 1530, 2, 645, 268, 303, 508, 83, 4, 2, 1531],
#  [49, 1530, 2, 645, 268, 303, 508, 83, 4, 2, 1531, 7],
#  [49, 1530, 2, 645, 268, 303, 508, 83, 4, 2, 1531, 7, 214],
#  [49, 1530, 2, 645, 268, 303, 508, 83, 4, 2, 1531, 7, 214, 645],
#  [49, 1530, 2, 645, 268, 303, 508, 83, 4, 2, 1531, 7, 214, 645, 268],
#  [49, 1530, 2, 645, 268, 303, 508, 83, 4, 2, 1531, 7, 214, 645, 268, 508],
#  [49, 1530, 2, 645, 268, 303, 508, 83, 4, 2, 1531, 7, 214, 645, 268, 508, 215],
#  [49,
#   1530,
#   2,
#   645,
#   268,
#   303,
#   508,
#   83,
#   4,
#   2,
#   1531,
#   7,
#   214,
#   645,
#   268,
#   508,
#   215,
#   9],
#  [49,
#   1530,
#   2,
#   645,
#   268,
#   303,
#   508,
#   83,
#   4,
#   2,
#   1531,
#   7,
#   214,
#   645,
#   268,
#   508,
#   215,
#   9,
#   12],
#  [49,
#   1530,
#   2,
#   645,
#   268,
#   303,
#   508,
#   83,
#   4,
#   2,
#   1531,
#   7,
#   214,
#   645,
#   268,
#   508,
#   215,
#   9,
#   12,
#   303],
#  [49,
#   1530,
#   2,
#   645,
#   268,
#   303,
#   508,
#   83,
#   4,
#   2,
#   1531,
#   7,
#   214,
#   645,
#   268,
#   508,
#   215,
#   9,
#   12,
#   303,
#   935],
#  [49,
#   1530,
#   2,
#   645,
#   268,
#   303,
#   508,
#   83,
#   4,
#   2,
#   1531,
#   7,
#   214,
#   645,
#   268,
#   508,
#   215,
#   9,
#   12,
#   303,
#   935,
#   88],
#  [49,
#   1530,
#   2,
#   645,
#   268,
#   303,
#   508,
#   83,
#   4,
#   2,
#   1531,
#   7,
#   214,
#   645,
#   268,
#   508,
#   215,
#   9,
#   12,
#   303,
#   935,
#   88,
#   646],
#  [49,
#   1530,
#   2,
#   645,
#   268,
#   303,
#   508,
#   83,
#   4,
#   2,
#   1531,
#   7,
#   214,
#   645,
#   268,
#   508,
#   215,
#   9,
#   12,
#   303,
#   935,
#   88,
#   646,
#   49],
#  [49,
#   1530,
#   2,
#   645,
#   268,
#   303,
#   508,
#   83,
#   4,
#   2,
#   1531,
#   7,
#   214,
#   645,
#   268,
#   508,
#   215,
#   9,
#   12,
#   303,
#   935,
#   88,
#   646,
#   49,
#   936],
#  [49,
#   1530,
#   2,
#   645,
#   268,
#   303,
#   508,
#   83,
#   4,
#   2,
#   1531,
#   7,
#   214,
#   645,
#   268,
#   508,
#   215,
#   9,
#   12,
#   303,
#   935,
#   88,
#   646,
#   49,
#   936,
#   268],
#  [49,
#   1530,
#   2,
#   645,
#   268,
#   303,
#   508,
#   83,
#   4,
#   2,
#   1531,
#   7,
#   214,
#   645,
#   268,
#   508,
#   215,
#   9,
#   12,
#   303,
#   935,
#   88,
#   646,
#   49,
#   936,
#   268,
#   646],
#  [49,
#   1530,
#   2,
#   645,
#   268,
#   303,
#   508,
#   83,
#   4,
#   2,
#   1531,
#   7,
#   214,
#   645,
#   268,
#   508,
#   215,
#   9,
#   12,
#   303,
#   935,
#   88,
#   646,
#   49,
#   936,
#   268,
#   646,
#   508],
#  [3, 304],
#  [3, 304, 30],
#  [3, 304, 30, 55],
#  [3, 304, 30, 55, 937],
#  [3, 304, 30, 55, 937, 647],
#  [3, 304, 30, 55, 937, 647, 50],
#  [3, 304, 30, 55, 937, 647, 50, 125],
#  [3, 304, 30, 55, 937, 647, 50, 125, 1],
#  [3, 304, 30, 55, 937, 647, 50, 125, 1, 93],
#  [3, 304, 30, 55, 937, 647, 50, 125, 1, 93, 160],
#  [3, 304, 30, 55, 937, 647, 50, 125, 1, 93, 160, 18],
#  [3, 304, 30, 55, 937, 647, 50, 125, 1, 93, 160, 18, 938],
#  [3, 304, 30, 55, 937, 647, 50, 125, 1, 93, 160, 18, 938, 269],
#  [3, 304, 30, 55, 937, 647, 50, 125, 1, 93, 160, 18, 938, 269, 38],
#  [3, 304, 30, 55, 937, 647, 50, 125, 1, 93, 160, 18, 938, 269, 38, 648],
#  [3, 304, 30, 55, 937, 647, 50, 125, 1, 93, 160, 18, 938, 269, 38, 648, 88],
#  [3,
#   304,
#   30,
#   55,
#   937,
#   647,
#   50,
#   125,
#   1,
#   93,
#   160,
#   18,
#   938,
#   269,
#   38,
#   648,
#   88,
#   52],
#  [3,
#   304,
#   30,
#   55,
#   937,
#   647,
#   50,
#   125,
#   1,
#   93,
#   160,
#   18,
#   938,
#   269,
#   38,
#   648,
#   88,
#   52,
#   1532],
#  [3,
#   304,
#   30,
#   55,
#   937,
#   647,
#   50,
#   125,
#   1,
#   93,
#   160,
#   18,
#   938,
#   269,
#   38,
#   648,
#   88,
#   52,
#   1532,
#   11],
#  [3,
#   304,
#   30,
#   55,
#   937,
#   647,
#   50,
#   125,
#   1,
#   93,
#   160,
#   18,
#   938,
#   269,
#   38,
#   648,
#   88,
#   52,
#   1532,
#   11,
#   9],
#  [3,
#   304,
#   30,
#   55,
#   937,
#   647,
#   50,
#   125,
#   1,
#   93,
#   160,
#   18,
#   938,
#   269,
#   38,
#   648,
#   88,
#   52,
#   1532,
#   11,
#   9,
#   939],
#  [3,
#   304,
#   30,
#   55,
#   937,
#   647,
#   50,
#   125,
#   1,
#   93,
#   160,
#   18,
#   938,
#   269,
#   38,
#   648,
#   88,
#   52,
#   1532,
#   11,
#   9,
#   939,
#   30],
#  [3,
#   304,
#   30,
#   55,
#   937,
#   647,
#   50,
#   125,
#   1,
#   93,
#   160,
#   18,
#   938,
#   269,
#   38,
#   648,
#   88,
#   52,
#   1532,
#   11,
#   9,
#   939,
#   30,
#   4],
#  [3,
#   304,
#   30,
#   55,
#   937,
#   647,
#   50,
#   125,
#   1,
#   93,
#   160,
#   18,
#   938,
#   269,
#   38,
#   648,
#   88,
#   52,
#   1532,
#   11,
#   9,
#   939,
#   30,
#   4,
#   34],
#  [3,
#   304,
#   30,
#   55,
#   937,
#   647,
#   50,
#   125,
#   1,
#   93,
#   160,
#   18,
#   938,
#   269,
#   38,
#   648,
#   88,
#   52,
#   1532,
#   11,
#   9,
#   939,
#   30,
#   4,
#   34,
#   1533],
#  [3,
#   304,
#   30,
#   55,
#   937,
#   647,
#   50,
#   125,
#   1,
#   93,
#   160,
#   18,
#   938,
#   269,
#   38,
#   648,
#   88,
#   52,
#   1532,
#   11,
#   9,
#   939,
#   30,
#   4,
#   34,
#   1533,
#   64],
#  [3,
#   304,
#   30,
#   55,
#   937,
#   647,
#   50,
#   125,
#   1,
#   93,
#   160,
#   18,
#   938,
#   269,
#   38,
#   648,
#   88,
#   52,
#   1532,
#   11,
#   9,
#   939,
#   30,
#   4,
#   34,
#   1533,
#   64,
#   2],
#  [3,
#   304,
#   30,
#   55,
#   937,
#   647,
#   50,
#   125,
#   1,
#   93,
#   160,
#   18,
#   938,
#   269,
#   38,
#   648,
#   88,
#   52,
#   1532,
#   11,
#   9,
#   939,
#   30,
#   4,
#   34,
#   1533,
#   64,
#   2,
#   649],
#  [11, 13],
#  [11, 13, 5],
#  [11, 13, 5, 54],
#  [11, 13, 5, 54, 1],
#  [11, 13, 5, 54, 1, 1534],
#  [11, 13, 5, 54, 1, 1534, 10],
#  [11, 13, 5, 54, 1, 1534, 10, 1535],
#  [11, 13, 5, 54, 1, 1534, 10, 1535, 1],
#  [11, 13, 5, 54, 1, 1534, 10, 1535, 1, 1536],
#  [3, 304],
#  [3, 304, 234],
#  [3, 304, 234, 18],
#  [3, 304, 234, 18, 57],
#  [3, 304, 234, 18, 57, 509],
#  [3, 304, 234, 18, 57, 509, 510],
#  [3, 304, 234, 18, 57, 509, 510, 1537],
#  [3, 304, 234, 18, 57, 509, 510, 1537, 26],
#  [3, 304, 234, 18, 57, 509, 510, 1537, 26, 420],
#  [3, 304, 234, 18, 57, 509, 510, 1537, 26, 420, 109],
#  [3, 304, 234, 18, 57, 509, 510, 1537, 26, 420, 109, 34],
#  [3, 304, 234, 18, 57, 509, 510, 1537, 26, 420, 109, 34, 2],
#  [3, 304, 234, 18, 57, 509, 510, 1537, 26, 420, 109, 34, 2, 1538],
#  [3, 304, 234, 18, 57, 509, 510, 1537, 26, 420, 109, 34, 2, 1538, 1539],
#  [3, 304, 234, 18, 57, 509, 510, 1537, 26, 420, 109, 34, 2, 1538, 1539, 26],
#  [3,
#   304,
#   234,
#   18,
#   57,
#   509,
#   510,
#   1537,
#   26,
#   420,
#   109,
#   34,
#   2,
#   1538,
#   1539,
#   26,
#   421],
#  [11, 69],
#  [11, 69, 5],
#  [11, 69, 5, 19],
#  [11, 69, 5, 19, 27],
#  [11, 69, 5, 19, 27, 31],
#  [11, 69, 5, 19, 27, 31, 1540],
#  [11, 69, 5, 19, 27, 31, 1540, 1541],
#  [11, 69, 5, 19, 27, 31, 1540, 1541, 15],
#  [11, 69, 5, 19, 27, 31, 1540, 1541, 15, 6],
#  [11, 69, 5, 19, 27, 31, 1540, 1541, 15, 6, 1542],
#  [11, 69, 5, 19, 27, 31, 1540, 1541, 15, 6, 1542, 1],
#  [11, 69, 5, 19, 27, 31, 1540, 1541, 15, 6, 1542, 1, 305],
#  [11, 69, 5, 19, 27, 31, 1540, 1541, 15, 6, 1542, 1, 305, 650],
#  [25, 1543],
#  [25, 1543, 64],
#  [25, 1543, 64, 1],
#  [25, 1543, 64, 1, 118],
#  [25, 1543, 64, 1, 118, 1],
#  [25, 1543, 64, 1, 118, 1, 651],
#  [25, 1543, 64, 1, 118, 1, 651, 101],
#  [25, 1543, 64, 1, 118, 1, 651, 101, 1544],
#  [25, 1543, 64, 1, 118, 1, 651, 101, 1544, 12],
#  [25, 1543, 64, 1, 118, 1, 651, 101, 1544, 12, 4],
#  [25, 1543, 64, 1, 118, 1, 651, 101, 1544, 12, 4, 1545],
#  [25, 1543, 64, 1, 118, 1, 651, 101, 1544, 12, 4, 1545, 422],
#  [25, 1543, 64, 1, 118, 1, 651, 101, 1544, 12, 4, 1545, 422, 47],
#  [25, 1543, 64, 1, 118, 1, 651, 101, 1544, 12, 4, 1545, 422, 47, 940],
#  [25, 1543, 64, 1, 118, 1, 651, 101, 1544, 12, 4, 1545, 422, 47, 940, 422],
#  [25, 1543, 64, 1, 118, 1, 651, 101, 1544, 12, 4, 1545, 422, 47, 940, 422, 39],
#  [25,
#   1543,
#   64,
#   1,
#   118,
#   1,
#   651,
#   101,
#   1544,
#   12,
#   4,
#   1545,
#   422,
#   47,
#   940,
#   422,
#   39,
#   511],
#  [25,
#   1543,
#   64,
#   1,
#   118,
#   1,
#   651,
#   101,
#   1544,
#   12,
#   4,
#   1545,
#   422,
#   47,
#   940,
#   422,
#   39,
#   511,
#   86],
#  [25,
#   1543,
#   64,
#   1,
#   118,
#   1,
#   651,
#   101,
#   1544,
#   12,
#   4,
#   1545,
#   422,
#   47,
#   940,
#   422,
#   39,
#   511,
#   86,
#   4],
#  [25,
#   1543,
#   64,
#   1,
#   118,
#   1,
#   651,
#   101,
#   1544,
#   12,
#   4,
#   1545,
#   422,
#   47,
#   940,
#   422,
#   39,
#   511,
#   86,
#   4,
#   270],
#  [25,
#   1543,
#   64,
#   1,
#   118,
#   1,
#   651,
#   101,
#   1544,
#   12,
#   4,
#   1545,
#   422,
#   47,
#   940,
#   422,
#   39,
#   511,
#   86,
#   4,
#   270,
#   11],
#  [25,
#   1543,
#   64,
#   1,
#   118,
#   1,
#   651,
#   101,
#   1544,
#   12,
#   4,
#   1545,
#   422,
#   47,
#   940,
#   422,
#   39,
#   511,
#   86,
#   4,
#   270,
#   11,
#   70],
#  [25,
#   1543,
#   64,
#   1,
#   118,
#   1,
#   651,
#   101,
#   1544,
#   12,
#   4,
#   1545,
#   422,
#   47,
#   940,
#   422,
#   39,
#   511,
#   86,
#   4,
#   270,
#   11,
#   70,
#   423],
#  [25,
#   1543,
#   64,
#   1,
#   118,
#   1,
#   651,
#   101,
#   1544,
#   12,
#   4,
#   1545,
#   422,
#   47,
#   940,
#   422,
#   39,
#   511,
#   86,
#   4,
#   270,
#   11,
#   70,
#   423,
#   36],
#  [3, 354],
#  [3, 354, 8],
#  [3, 354, 8, 175],
#  [3, 354, 8, 175, 4],
#  [3, 354, 8, 175, 4, 941],
#  [3, 354, 8, 175, 4, 941, 1546],
#  [3, 354, 8, 175, 4, 941, 1546, 3],
#  [3, 354, 8, 175, 4, 941, 1546, 3, 306],
#  [3, 354, 8, 175, 4, 941, 1546, 3, 306, 9],
#  [3, 354, 8, 175, 4, 941, 1546, 3, 306, 9, 76],
#  [3, 354, 8, 175, 4, 941, 1546, 3, 306, 9, 76, 355],
#  [3, 354, 8, 175, 4, 941, 1546, 3, 306, 9, 76, 355, 512],
#  [3, 354, 8, 175, 4, 941, 1546, 3, 306, 9, 76, 355, 512, 7],
#  [3, 354, 8, 175, 4, 941, 1546, 3, 306, 9, 76, 355, 512, 7, 161],
#  [3, 354, 8, 175, 4, 941, 1546, 3, 306, 9, 76, 355, 512, 7, 161, 77],
#  [3, 354, 8, 175, 4, 941, 1546, 3, 306, 9, 76, 355, 512, 7, 161, 77, 1],
#  [3, 354, 8, 175, 4, 941, 1546, 3, 306, 9, 76, 355, 512, 7, 161, 77, 1, 652],
#  [3,
#   354,
#   8,
#   175,
#   4,
#   941,
#   1546,
#   3,
#   306,
#   9,
#   76,
#   355,
#   512,
#   7,
#   161,
#   77,
#   1,
#   652,
#   1547],
#  [3,
#   354,
#   8,
#   175,
#   4,
#   941,
#   1546,
#   3,
#   306,
#   9,
#   76,
#   355,
#   512,
#   7,
#   161,
#   77,
#   1,
#   652,
#   1547,
#   16],
#  [3,
#   354,
#   8,
#   175,
#   4,
#   941,
#   1546,
#   3,
#   306,
#   9,
#   76,
#   355,
#   512,
#   7,
#   161,
#   77,
#   1,
#   652,
#   1547,
#   16,
#   11],
#  [3,
#   354,
#   8,
#   175,
#   4,
#   941,
#   1546,
#   3,
#   306,
#   9,
#   76,
#   355,
#   512,
#   7,
#   161,
#   77,
#   1,
#   652,
#   1547,
#   16,
#   11,
#   356],
#  [3,
#   354,
#   8,
#   175,
#   4,
#   941,
#   1546,
#   3,
#   306,
#   9,
#   76,
#   355,
#   512,
#   7,
#   161,
#   77,
#   1,
#   652,
#   1547,
#   16,
#   11,
#   356,
#   4],
#  [3,
#   354,
#   8,
#   175,
#   4,
#   941,
#   1546,
#   3,
#   306,
#   9,
#   76,
#   355,
#   512,
#   7,
#   161,
#   77,
#   1,
#   652,
#   1547,
#   16,
#   11,
#   356,
#   4,
#   9],
#  [196, 1],
#  [196, 1, 1548],
#  [196, 1, 1548, 357],
#  [196, 1, 1548, 357, 1549],
#  [196, 1, 1548, 357, 1549, 1550],
#  [196, 1, 1548, 357, 1549, 1550, 62],
#  [196, 1, 1548, 357, 1549, 1550, 62, 942],
#  [11, 23],
#  [11, 23, 513],
#  [11, 23, 513, 91],
#  [11, 23, 513, 91, 653],
#  [11, 23, 513, 91, 653, 216],
#  [11, 23, 513, 91, 653, 216, 26],
#  [11, 23, 513, 91, 653, 216, 26, 74],
#  [11, 23, 513, 91, 653, 216, 26, 74, 6],
#  [11, 23, 513, 91, 653, 216, 26, 74, 6, 2],
#  [11, 23, 513, 91, 653, 216, 26, 74, 6, 2, 217],
#  [11, 23, 513, 91, 653, 216, 26, 74, 6, 2, 217, 34],
#  [11, 23, 513, 91, 653, 216, 26, 74, 6, 2, 217, 34, 6],
#  [11, 23, 513, 91, 653, 216, 26, 74, 6, 2, 217, 34, 6, 2],
#  [11, 23, 513, 91, 653, 216, 26, 74, 6, 2, 217, 34, 6, 2, 217],
#  [11, 943],
#  [11, 943, 25],
#  [11, 943, 25, 5],
#  [11, 943, 25, 5, 34],
#  [11, 943, 25, 5, 34, 31],
#  [11, 943, 25, 5, 34, 31, 119],
#  [11, 943, 25, 5, 34, 31, 119, 514],
#  [11, 943, 25, 5, 34, 31, 119, 514, 5],
#  [11, 943, 25, 5, 34, 31, 119, 514, 5, 944],
#  [11, 943, 25, 5, 34, 31, 119, 514, 5, 944, 1],
#  [11, 943, 25, 5, 34, 31, 119, 514, 5, 944, 1, 1551],
#  [11, 943, 25, 5, 34, 31, 119, 514, 5, 944, 1, 1551, 50],
#  [11, 943, 25, 5, 34, 31, 119, 514, 5, 944, 1, 1551, 50, 44],
#  [11, 943, 25, 5, 34, 31, 119, 514, 5, 944, 1, 1551, 50, 44, 945],
#  [49, 176],
#  [49, 176, 177],
#  [49, 176, 177, 4],
#  [49, 176, 177, 4, 2],
#  [49, 176, 177, 4, 2, 946],
#  [49, 176, 177, 4, 2, 946, 1552],
#  [49, 176, 177, 4, 2, 946, 1552, 2],
#  [49, 176, 177, 4, 2, 946, 1552, 2, 947],
#  [49, 176, 177, 4, 2, 946, 1552, 2, 947, 2],
#  [49, 176, 177, 4, 2, 946, 1552, 2, 947, 2, 1553],
#  [49, 176, 177, 4, 2, 946, 1552, 2, 947, 2, 1553, 32],
#  [49, 176, 177, 4, 2, 946, 1552, 2, 947, 2, 1553, 32, 26],
#  [49, 176, 177, 4, 2, 946, 1552, 2, 947, 2, 1553, 32, 26, 424],
#  [49, 176, 177, 4, 2, 946, 1552, 2, 947, 2, 1553, 32, 26, 424, 1554],
#  [49, 176, 177, 4, 2, 946, 1552, 2, 947, 2, 1553, 32, 26, 424, 1554, 1555],
#  [49,
#   176,
#   177,
#   4,
#   2,
#   946,
#   1552,
#   2,
#   947,
#   2,
#   1553,
#   32,
#   26,
#   424,
#   1554,
#   1555,
#   1556],
#  [49,
#   176,
#   177,
#   4,
#   2,
#   946,
#   1552,
#   2,
#   947,
#   2,
#   1553,
#   32,
#   26,
#   424,
#   1554,
#   1555,
#   1556,
#   2],
#  [49,
#   176,
#   177,
#   4,
#   2,
#   946,
#   1552,
#   2,
#   947,
#   2,
#   1553,
#   32,
#   26,
#   424,
#   1554,
#   1555,
#   1556,
#   2,
#   162],
#  [49,
#   176,
#   177,
#   4,
#   2,
#   946,
#   1552,
#   2,
#   947,
#   2,
#   1553,
#   32,
#   26,
#   424,
#   1554,
#   1555,
#   1556,
#   2,
#   162,
#   425],
#  [49,
#   176,
#   177,
#   4,
#   2,
#   946,
#   1552,
#   2,
#   947,
#   2,
#   1553,
#   32,
#   26,
#   424,
#   1554,
#   1555,
#   1556,
#   2,
#   162,
#   425,
#   28],
#  [49,
#   176,
#   177,
#   4,
#   2,
#   946,
#   1552,
#   2,
#   947,
#   2,
#   1553,
#   32,
#   26,
#   424,
#   1554,
#   1555,
#   1556,
#   2,
#   162,
#   425,
#   28,
#   120],
#  [49,
#   176,
#   177,
#   4,
#   2,
#   946,
#   1552,
#   2,
#   947,
#   2,
#   1553,
#   32,
#   26,
#   424,
#   1554,
#   1555,
#   1556,
#   2,
#   162,
#   425,
#   28,
#   120,
#   1557],
#  [49,
#   176,
#   177,
#   4,
#   2,
#   946,
#   1552,
#   2,
#   947,
#   2,
#   1553,
#   32,
#   26,
#   424,
#   1554,
#   1555,
#   1556,
#   2,
#   162,
#   425,
#   28,
#   120,
#   1557,
#   82],
#  [49,
#   176,
#   177,
#   4,
#   2,
#   946,
#   1552,
#   2,
#   947,
#   2,
#   1553,
#   32,
#   26,
#   424,
#   1554,
#   1555,
#   1556,
#   2,
#   162,
#   425,
#   28,
#   120,
#   1557,
#   82,
#   163],
#  [11, 23],
#  [11, 23, 2],
#  [11, 23, 2, 948],
#  [11, 23, 2, 948, 48],
#  [11, 23, 2, 948, 48, 25],
#  [11, 23, 2, 948, 48, 25, 22],
#  [11, 23, 2, 948, 48, 25, 22, 306],
#  [11, 23, 2, 948, 48, 25, 22, 306, 2],
#  [11, 23, 2, 948, 48, 25, 22, 306, 2, 949],
#  [11, 23, 2, 948, 48, 25, 22, 306, 2, 949, 4],
#  [11, 23, 2, 948, 48, 25, 22, 306, 2, 949, 4, 2],
#  [11, 23, 2, 948, 48, 25, 22, 306, 2, 949, 4, 2, 654],
#  [11, 23, 2, 948, 48, 25, 22, 306, 2, 949, 4, 2, 654, 27],
#  [11, 23, 2, 948, 48, 25, 22, 306, 2, 949, 4, 2, 654, 27, 5],
#  [11, 23, 2, 948, 48, 25, 22, 306, 2, 949, 4, 2, 654, 27, 5, 94],
#  [11, 23, 2, 948, 48, 25, 22, 306, 2, 949, 4, 2, 654, 27, 5, 94, 515],
#  [11, 23, 2, 948, 48, 25, 22, 306, 2, 949, 4, 2, 654, 27, 5, 94, 515, 950],
#  [11,
#   23,
#   2,
#   948,
#   48,
#   25,
#   22,
#   306,
#   2,
#   949,
#   4,
#   2,
#   654,
#   27,
#   5,
#   94,
#   515,
#   950,
#   235],
#  [11,
#   23,
#   2,
#   948,
#   48,
#   25,
#   22,
#   306,
#   2,
#   949,
#   4,
#   2,
#   654,
#   27,
#   5,
#   94,
#   515,
#   950,
#   235,
#   950],
#  [51, 2],
#  [51, 2, 164],
#  [51, 2, 164, 307],
#  [51, 2, 164, 307, 10],
#  [51, 2, 164, 307, 10, 516],
#  [51, 2, 164, 307, 10, 516, 18],
#  [51, 2, 164, 307, 10, 516, 18, 31],
#  [51, 2, 164, 307, 10, 516, 18, 31, 1558],
#  [51, 2, 164, 307, 10, 516, 18, 31, 1558, 1559],
#  [11, 23],
#  [11, 23, 40],
#  [11, 23, 40, 358],
#  [11, 23, 40, 358, 48],
#  [11, 23, 40, 358, 48, 4],
#  [11, 23, 40, 358, 48, 4, 2],
#  [11, 23, 40, 358, 48, 4, 2, 95],
#  [11, 23, 40, 358, 48, 4, 2, 95, 29],
#  [11, 23, 40, 358, 48, 4, 2, 95, 29, 5],
#  [11, 23, 40, 358, 48, 4, 2, 95, 29, 5, 358],
#  [11, 23, 40, 358, 48, 4, 2, 95, 29, 5, 358, 218],
#  [43, 424],
#  [43, 424, 14],
#  [43, 424, 14, 655],
#  [43, 424, 14, 655, 655],
#  [43, 424, 14, 655, 655, 3],
#  [43, 424, 14, 655, 655, 3, 19],
#  [43, 424, 14, 655, 655, 3, 19, 1],
#  [43, 424, 14, 655, 655, 3, 19, 1, 656],
#  [517, 12],
#  [517, 12, 30],
#  [517, 12, 30, 24],
#  [517, 12, 30, 24, 1560],
#  [517, 12, 30, 24, 1560, 9],
#  [517, 12, 30, 24, 1560, 9, 177],
#  [517, 12, 30, 24, 1560, 9, 177, 657],
#  [517, 12, 30, 24, 1560, 9, 177, 657, 7],
#  [517, 12, 30, 24, 1560, 9, 177, 657, 7, 657],
#  [517, 12, 30, 24, 1560, 9, 177, 657, 7, 657, 105],
#  [517, 12, 30, 24, 1560, 9, 177, 657, 7, 657, 105, 184],
#  [517, 12, 30, 24, 1560, 9, 177, 657, 7, 657, 105, 184, 951],
#  [308, 1561],
#  [308, 1561, 952],
#  [308, 1561, 952, 136],
#  [308, 1561, 952, 136, 96],
#  [308, 1561, 952, 136, 96, 185],
#  [308, 1561, 952, 136, 96, 185, 359],
#  [308, 1561, 952, 136, 96, 185, 359, 6],
#  [308, 1561, 952, 136, 96, 185, 359, 6, 518],
#  [1562, 3],
#  [1562, 3, 110],
#  [1562, 3, 110, 57],
#  [1562, 3, 110, 57, 218],
#  [1562, 3, 110, 57, 218, 1563],
#  [1562, 3, 110, 57, 218, 1563, 953],
#  [1562, 3, 110, 57, 218, 1563, 953, 3],
#  [1562, 3, 110, 57, 218, 1563, 953, 3, 954],
#  [1562, 3, 110, 57, 218, 1563, 953, 3, 954, 26],
#  [1562, 3, 110, 57, 218, 1563, 953, 3, 954, 26, 28],
#  [1562, 3, 110, 57, 218, 1563, 953, 3, 954, 26, 28, 1564],
#  [1562, 3, 110, 57, 218, 1563, 953, 3, 954, 26, 28, 1564, 2],
#  [1562, 3, 110, 57, 218, 1563, 953, 3, 954, 26, 28, 1564, 2, 164],
#  [1562, 3, 110, 57, 218, 1563, 953, 3, 954, 26, 28, 1564, 2, 164, 236],
#  [1562, 3, 110, 57, 218, 1563, 953, 3, 954, 26, 28, 1564, 2, 164, 236, 4],
#  [1562, 3, 110, 57, 218, 1563, 953, 3, 954, 26, 28, 1564, 2, 164, 236, 4, 658],
#  [1562,
#   3,
#   110,
#   57,
#   218,
#   1563,
#   953,
#   3,
#   954,
#   26,
#   28,
#   1564,
#   2,
#   164,
#   236,
#   4,
#   658,
#   2],
#  [1562,
#   3,
#   110,
#   57,
#   218,
#   1563,
#   953,
#   3,
#   954,
#   26,
#   28,
#   1564,
#   2,
#   164,
#   236,
#   4,
#   658,
#   2,
#   426],
#  [1562,
#   3,
#   110,
#   57,
#   218,
#   1563,
#   953,
#   3,
#   954,
#   26,
#   28,
#   1564,
#   2,
#   164,
#   236,
#   4,
#   658,
#   2,
#   426,
#   10],
#  [1562,
#   3,
#   110,
#   57,
#   218,
#   1563,
#   953,
#   3,
#   954,
#   26,
#   28,
#   1564,
#   2,
#   164,
#   236,
#   4,
#   658,
#   2,
#   426,
#   10,
#   219],
#  [1562,
#   3,
#   110,
#   57,
#   218,
#   1563,
#   953,
#   3,
#   954,
#   26,
#   28,
#   1564,
#   2,
#   164,
#   236,
#   4,
#   658,
#   2,
#   426,
#   10,
#   219,
#   7],
#  [1562,
#   3,
#   110,
#   57,
#   218,
#   1563,
#   953,
#   3,
#   954,
#   26,
#   28,
#   1564,
#   2,
#   164,
#   236,
#   4,
#   658,
#   2,
#   426,
#   10,
#   219,
#   7,
#   519],
#  [1562,
#   3,
#   110,
#   57,
#   218,
#   1563,
#   953,
#   3,
#   954,
#   26,
#   28,
#   1564,
#   2,
#   164,
#   236,
#   4,
#   658,
#   2,
#   426,
#   10,
#   219,
#   7,
#   519,
#   197],
#  [1562,
#   3,
#   110,
#   57,
#   218,
#   1563,
#   953,
#   3,
#   954,
#   26,
#   28,
#   1564,
#   2,
#   164,
#   236,
#   4,
#   658,
#   2,
#   426,
#   10,
#   219,
#   7,
#   519,
#   197,
#   659],
#  [8, 78],
#  [8, 78, 152],
#  [8, 78, 152, 14],
#  [8, 78, 152, 14, 4],
#  [8, 78, 152, 14, 4, 79],
#  [8, 78, 152, 14, 4, 79, 1],
#  [8, 78, 152, 14, 4, 79, 1, 1565],
#  [8, 78, 152, 14, 4, 79, 1, 1565, 37],
#  [8, 78, 152, 14, 4, 79, 1, 1565, 37, 360],
#  [8, 78, 152, 14, 4, 79, 1, 1565, 37, 360, 10],
#  [8, 78, 152, 14, 4, 79, 1, 1565, 37, 360, 10, 1566],
#  [8, 78, 152, 14, 4, 79, 1, 1565, 37, 360, 10, 1566, 9],
#  [8, 78, 152, 14, 4, 79, 1, 1565, 37, 360, 10, 1566, 9, 71],
#  [8, 78, 152, 14, 4, 79, 1, 1565, 37, 360, 10, 1566, 9, 71, 144],
#  [8, 78, 152, 14, 4, 79, 1, 1565, 37, 360, 10, 1566, 9, 71, 144, 37],
#  [8, 78, 152, 14, 4, 79, 1, 1565, 37, 360, 10, 1566, 9, 71, 144, 37, 7],
#  [8, 78, 152, 14, 4, 79, 1, 1565, 37, 360, 10, 1566, 9, 71, 144, 37, 7, 73],
#  [8,
#   78,
#   152,
#   14,
#   4,
#   79,
#   1,
#   1565,
#   37,
#   360,
#   10,
#   1566,
#   9,
#   71,
#   144,
#   37,
#   7,
#   73,
#   520],
#  [8,
#   78,
#   152,
#   14,
#   4,
#   79,
#   1,
#   1565,
#   37,
#   360,
#   10,
#   1566,
#   9,
#   71,
#   144,
#   37,
#   7,
#   73,
#   520,
#   660],
#  [8,
#   78,
#   152,
#   14,
#   4,
#   79,
#   1,
#   1565,
#   37,
#   360,
#   10,
#   1566,
#   9,
#   71,
#   144,
#   37,
#   7,
#   73,
#   520,
#   660,
#   111],
#  [8,
#   78,
#   152,
#   14,
#   4,
#   79,
#   1,
#   1565,
#   37,
#   360,
#   10,
#   1566,
#   9,
#   71,
#   144,
#   37,
#   7,
#   73,
#   520,
#   660,
#   111,
#   22],
#  [8,
#   78,
#   152,
#   14,
#   4,
#   79,
#   1,
#   1565,
#   37,
#   360,
#   10,
#   1566,
#   9,
#   71,
#   144,
#   37,
#   7,
#   73,
#   520,
#   660,
#   111,
#   22,
#   309],
#  [8,
#   78,
#   152,
#   14,
#   4,
#   79,
#   1,
#   1565,
#   37,
#   360,
#   10,
#   1566,
#   9,
#   71,
#   144,
#   37,
#   7,
#   73,
#   520,
#   660,
#   111,
#   22,
#   309,
#   4],
#  [8,
#   78,
#   152,
#   14,
#   4,
#   79,
#   1,
#   1565,
#   37,
#   360,
#   10,
#   1566,
#   9,
#   71,
#   144,
#   37,
#   7,
#   73,
#   520,
#   660,
#   111,
#   22,
#   309,
#   4,
#   33],
#  [8,
#   78,
#   152,
#   14,
#   4,
#   79,
#   1,
#   1565,
#   37,
#   360,
#   10,
#   1566,
#   9,
#   71,
#   144,
#   37,
#   7,
#   73,
#   520,
#   660,
#   111,
#   22,
#   309,
#   4,
#   33,
#   1],
#  [8,
#   78,
#   152,
#   14,
#   4,
#   79,
#   1,
#   1565,
#   37,
#   360,
#   10,
#   1566,
#   9,
#   71,
#   144,
#   37,
#   7,
#   73,
#   520,
#   660,
#   111,
#   22,
#   309,
#   4,
#   33,
#   1,
#   1567],
#  [8,
#   78,
#   152,
#   14,
#   4,
#   79,
#   1,
#   1565,
#   37,
#   360,
#   10,
#   1566,
#   9,
#   71,
#   144,
#   37,
#   7,
#   73,
#   520,
#   660,
#   111,
#   22,
#   309,
#   4,
#   33,
#   1,
#   1567,
#   1568],
#  [56, 3],
#  [56, 3, 955],
#  [56, 3, 955, 8],
#  [56, 3, 955, 8, 521],
#  [56, 3, 955, 8, 521, 6],
#  [56, 3, 955, 8, 521, 6, 82],
#  [56, 3, 955, 8, 521, 6, 82, 1569],
#  [56, 3, 955, 8, 521, 6, 82, 1569, 3],
#  [56, 3, 955, 8, 521, 6, 82, 1569, 3, 361],
#  [56, 3, 955, 8, 521, 6, 82, 1569, 3, 361, 4],
#  [56, 3, 955, 8, 521, 6, 82, 1569, 3, 361, 4, 220],
#  [56, 3, 955, 8, 521, 6, 82, 1569, 3, 361, 4, 220, 11],
#  [56, 3, 955, 8, 521, 6, 82, 1569, 3, 361, 4, 220, 11, 661],
#  [56, 3, 955, 8, 521, 6, 82, 1569, 3, 361, 4, 220, 11, 661, 271],
#  [56, 3, 955, 8, 521, 6, 82, 1569, 3, 361, 4, 220, 11, 661, 271, 956],
#  [56, 3, 955, 8, 521, 6, 82, 1569, 3, 361, 4, 220, 11, 661, 271, 956, 77],
#  [56, 3, 955, 8, 521, 6, 82, 1569, 3, 361, 4, 220, 11, 661, 271, 956, 77, 237],
#  [56,
#   3,
#   955,
#   8,
#   521,
#   6,
#   82,
#   1569,
#   3,
#   361,
#   4,
#   220,
#   11,
#   661,
#   271,
#   956,
#   77,
#   237,
#   662],
#  [56,
#   3,
#   955,
#   8,
#   521,
#   6,
#   82,
#   1569,
#   3,
#   361,
#   4,
#   220,
#   11,
#   661,
#   271,
#   956,
#   77,
#   237,
#   662,
#   957],
#  [56,
#   3,
#   955,
#   8,
#   521,
#   6,
#   82,
#   1569,
#   3,
#   361,
#   4,
#   220,
#   11,
#   661,
#   271,
#   956,
#   77,
#   237,
#   662,
#   957,
#   1570],
#  [56,
#   3,
#   955,
#   8,
#   521,
#   6,
#   82,
#   1569,
#   3,
#   361,
#   4,
#   220,
#   11,
#   661,
#   271,
#   956,
#   77,
#   237,
#   662,
#   957,
#   1570,
#   46],
#  [56,
#   3,
#   955,
#   8,
#   521,
#   6,
#   82,
#   1569,
#   3,
#   361,
#   4,
#   220,
#   11,
#   661,
#   271,
#   956,
#   77,
#   237,
#   662,
#   957,
#   1570,
#   46,
#   102],
#  [56,
#   3,
#   955,
#   8,
#   521,
#   6,
#   82,
#   1569,
#   3,
#   361,
#   4,
#   220,
#   11,
#   661,
#   271,
#   956,
#   77,
#   237,
#   662,
#   957,
#   1570,
#   46,
#   102,
#   2],
#  [56,
#   3,
#   955,
#   8,
#   521,
#   6,
#   82,
#   1569,
#   3,
#   361,
#   4,
#   220,
#   11,
#   661,
#   271,
#   956,
#   77,
#   237,
#   662,
#   957,
#   1570,
#   46,
#   102,
#   2,
#   1571],
#  [66, 958],
#  [66, 958, 1572],
#  [66, 958, 1572, 59],
#  [66, 958, 1572, 59, 96],
#  [66, 958, 1572, 59, 96, 238],
#  [66, 958, 1572, 59, 96, 238, 1573],
#  [66, 958, 1572, 59, 96, 238, 1573, 272],
#  [66, 958, 1572, 59, 96, 238, 1573, 272, 237],
#  [3, 144],
#  [3, 144, 18],
#  [3, 144, 18, 1],
#  [3, 144, 18, 1, 273],
#  [3, 144, 18, 1, 273, 6],
#  [3, 144, 18, 1, 273, 6, 239],
#  [3, 144, 18, 1, 273, 6, 239, 42],
#  [3, 144, 18, 1, 273, 6, 239, 42, 178],
#  [3, 144, 18, 1, 273, 6, 239, 42, 178, 198],
#  [3, 144, 18, 1, 273, 6, 239, 42, 178, 198, 105],
#  [3, 144, 18, 1, 273, 6, 239, 42, 178, 198, 105, 103],
#  [3, 144, 18, 1, 273, 6, 239, 42, 178, 198, 105, 103, 310],
#  [3, 144, 18, 1, 273, 6, 239, 42, 178, 198, 105, 103, 310, 1574],
#  [3, 144, 18, 1, 273, 6, 239, 42, 178, 198, 105, 103, 310, 1574, 3],
#  [3, 144, 18, 1, 273, 6, 239, 42, 178, 198, 105, 103, 310, 1574, 3, 522],
#  [3, 144, 18, 1, 273, 6, 239, 42, 178, 198, 105, 103, 310, 1574, 3, 522, 186],
#  [3,
#   144,
#   18,
#   1,
#   273,
#   6,
#   239,
#   42,
#   178,
#   198,
#   105,
#   103,
#   310,
#   1574,
#   3,
#   522,
#   186,
#   3],
#  [3,
#   144,
#   18,
#   1,
#   273,
#   6,
#   239,
#   42,
#   178,
#   198,
#   105,
#   103,
#   310,
#   1574,
#   3,
#   522,
#   186,
#   3,
#   522],
#  [3,
#   144,
#   18,
#   1,
#   273,
#   6,
#   239,
#   42,
#   178,
#   198,
#   105,
#   103,
#   310,
#   1574,
#   3,
#   522,
#   186,
#   3,
#   522,
#   21],
#  [3,
#   144,
#   18,
#   1,
#   273,
#   6,
#   239,
#   42,
#   178,
#   198,
#   105,
#   103,
#   310,
#   1574,
#   3,
#   522,
#   186,
#   3,
#   522,
#   21,
#   45],
#  [3,
#   144,
#   18,
#   1,
#   273,
#   6,
#   239,
#   42,
#   178,
#   198,
#   105,
#   103,
#   310,
#   1574,
#   3,
#   522,
#   186,
#   3,
#   522,
#   21,
#   45,
#   41],
#  [3,
#   144,
#   18,
#   1,
#   273,
#   6,
#   239,
#   42,
#   178,
#   198,
#   105,
#   103,
#   310,
#   1574,
#   3,
#   522,
#   186,
#   3,
#   522,
#   21,
#   45,
#   41,
#   311],
#  [3,
#   144,
#   18,
#   1,
#   273,
#   6,
#   239,
#   42,
#   178,
#   198,
#   105,
#   103,
#   310,
#   1574,
#   3,
#   522,
#   186,
#   3,
#   522,
#   21,
#   45,
#   41,
#   311,
#   21],
#  [3,
#   144,
#   18,
#   1,
#   273,
#   6,
#   239,
#   42,
#   178,
#   198,
#   105,
#   103,
#   310,
#   1574,
#   3,
#   522,
#   186,
#   3,
#   522,
#   21,
#   45,
#   41,
#   311,
#   21,
#   3],
#  [3,
#   144,
#   18,
#   1,
#   273,
#   6,
#   239,
#   42,
#   178,
#   198,
#   105,
#   103,
#   310,
#   1574,
#   3,
#   522,
#   186,
#   3,
#   522,
#   21,
#   45,
#   41,
#   311,
#   21,
#   3,
#   65],
#  [3,
#   144,
#   18,
#   1,
#   273,
#   6,
#   239,
#   42,
#   178,
#   198,
#   105,
#   103,
#   310,
#   1574,
#   3,
#   522,
#   186,
#   3,
#   522,
#   21,
#   45,
#   41,
#   311,
#   21,
#   3,
#   65,
#   98],
#  [3,
#   144,
#   18,
#   1,
#   273,
#   6,
#   239,
#   42,
#   178,
#   198,
#   105,
#   103,
#   310,
#   1574,
#   3,
#   522,
#   186,
#   3,
#   522,
#   21,
#   45,
#   41,
#   311,
#   21,
#   3,
#   65,
#   98,
#   273],
#  [3,
#   144,
#   18,
#   1,
#   273,
#   6,
#   239,
#   42,
#   178,
#   198,
#   105,
#   103,
#   310,
#   1574,
#   3,
#   522,
#   186,
#   3,
#   522,
#   21,
#   45,
#   41,
#   311,
#   21,
#   3,
#   65,
#   98,
#   273,
#   18],
#  [3,
#   144,
#   18,
#   1,
#   273,
#   6,
#   239,
#   42,
#   178,
#   198,
#   105,
#   103,
#   310,
#   1574,
#   3,
#   522,
#   186,
#   3,
#   522,
#   21,
#   45,
#   41,
#   311,
#   21,
#   3,
#   65,
#   98,
#   273,
#   18,
#   103],
#  [3,
#   144,
#   18,
#   1,
#   273,
#   6,
#   239,
#   42,
#   178,
#   198,
#   105,
#   103,
#   310,
#   1574,
#   3,
#   522,
#   186,
#   3,
#   522,
#   21,
#   45,
#   41,
#   311,
#   21,
#   3,
#   65,
#   98,
#   273,
#   18,
#   103,
#   310],
#  [39, 959],
#  [39, 959, 1],
#  [39, 959, 1, 523],
#  [39, 959, 1, 523, 960],
#  [39, 959, 1, 523, 960, 1575],
#  [39, 959, 1, 523, 960, 1575, 10],
#  [39, 959, 1, 523, 960, 1575, 10, 1],
#  [39, 959, 1, 523, 960, 1575, 10, 1, 1576],
#  [39, 959, 1, 523, 960, 1575, 10, 1, 1576, 1577],
#  [39, 959, 1, 523, 960, 1575, 10, 1, 1576, 1577, 198],
#  [39, 959, 1, 523, 960, 1575, 10, 1, 1576, 1577, 198, 62],
#  [39, 959, 1, 523, 960, 1575, 10, 1, 1576, 1577, 198, 62, 1578],
#  [39, 959, 1, 523, 960, 1575, 10, 1, 1576, 1577, 198, 62, 1578, 4],
#  [39, 959, 1, 523, 960, 1575, 10, 1, 1576, 1577, 198, 62, 1578, 4, 35],
#  [39, 959, 1, 523, 960, 1575, 10, 1, 1576, 1577, 198, 62, 1578, 4, 35, 362],
#  [39,
#   959,
#   1,
#   523,
#   960,
#   1575,
#   10,
#   1,
#   1576,
#   1577,
#   198,
#   62,
#   1578,
#   4,
#   35,
#   362,
#   49],
#  [39,
#   959,
#   1,
#   523,
#   960,
#   1575,
#   10,
#   1,
#   1576,
#   1577,
#   198,
#   62,
#   1578,
#   4,
#   35,
#   362,
#   49,
#   312],
#  [39,
#   959,
#   1,
#   523,
#   960,
#   1575,
#   10,
#   1,
#   1576,
#   1577,
#   198,
#   62,
#   1578,
#   4,
#   35,
#   362,
#   49,
#   312,
#   38],
#  [39,
#   959,
#   1,
#   523,
#   960,
#   1575,
#   10,
#   1,
#   1576,
#   1577,
#   198,
#   62,
#   1578,
#   4,
#   35,
#   362,
#   49,
#   312,
#   38,
#   67],
#  [39,
#   959,
#   1,
#   523,
#   960,
#   1575,
#   10,
#   1,
#   1576,
#   1577,
#   198,
#   62,
#   1578,
#   4,
#   35,
#   362,
#   49,
#   312,
#   38,
#   67,
#   56],
#  [39,
#   959,
#   1,
#   523,
#   960,
#   1575,
#   10,
#   1,
#   1576,
#   1577,
#   198,
#   62,
#   1578,
#   4,
#   35,
#   362,
#   49,
#   312,
#   38,
#   67,
#   56,
#   27],
#  [39,
#   959,
#   1,
#   523,
#   960,
#   1575,
#   10,
#   1,
#   1576,
#   1577,
#   198,
#   62,
#   1578,
#   4,
#   35,
#   362,
#   49,
#   312,
#   38,
#   67,
#   56,
#   27,
#   4],
#  [39,
#   959,
#   1,
#   523,
#   960,
#   1575,
#   10,
#   1,
#   1576,
#   1577,
#   198,
#   62,
#   1578,
#   4,
#   35,
#   362,
#   49,
#   312,
#   38,
#   67,
#   56,
#   27,
#   4,
#   48],
#  [39,
#   959,
#   1,
#   523,
#   960,
#   1575,
#   10,
#   1,
#   1576,
#   1577,
#   198,
#   62,
#   1578,
#   4,
#   35,
#   362,
#   49,
#   312,
#   38,
#   67,
#   56,
#   27,
#   4,
#   48,
#   112],
#  [39,
#   959,
#   1,
#   523,
#   960,
#   1575,
#   10,
#   1,
#   1576,
#   1577,
#   198,
#   62,
#   1578,
#   4,
#   35,
#   362,
#   49,
#   312,
#   38,
#   67,
#   56,
#   27,
#   4,
#   48,
#   112,
#   5],
#  [39,
#   959,
#   1,
#   523,
#   960,
#   1575,
#   10,
#   1,
#   1576,
#   1577,
#   198,
#   62,
#   1578,
#   4,
#   35,
#   362,
#   49,
#   312,
#   38,
#   67,
#   56,
#   27,
#   4,
#   48,
#   112,
#   5,
#   313],
#  [3, 84],
#  [3, 84, 85],
#  [3, 84, 85, 517],
#  [3, 84, 85, 517, 1],
#  [3, 84, 85, 517, 1, 663],
#  [3, 84, 85, 517, 1, 663, 49],
#  [3, 84, 85, 517, 1, 663, 49, 1579],
#  [3, 84, 85, 517, 1, 663, 49, 1579, 4],
#  [3, 84, 85, 517, 1, 663, 49, 1579, 4, 33],
#  [3, 84, 85, 517, 1, 663, 49, 1579, 4, 33, 24],
#  [3, 84, 85, 517, 1, 663, 49, 1579, 4, 33, 24, 1580],
#  [3, 84, 85, 517, 1, 663, 49, 1579, 4, 33, 24, 1580, 32],
#  [3, 84, 85, 517, 1, 663, 49, 1579, 4, 33, 24, 1580, 32, 961],
#  [3, 84, 85, 517, 1, 663, 49, 1579, 4, 33, 24, 1580, 32, 961, 85],
#  [3, 84, 85, 517, 1, 663, 49, 1579, 4, 33, 24, 1580, 32, 961, 85, 962],
#  [8, 237],
#  [8, 237, 28],
#  [8, 237, 28, 2],
#  [8, 237, 28, 2, 524],
#  [8, 237, 28, 2, 524, 1581],
#  [8, 237, 28, 2, 524, 1581, 28],
#  [8, 237, 28, 2, 524, 1581, 28, 509],
#  [8, 237, 28, 2, 524, 1581, 28, 509, 105],
#  [8, 237, 28, 2, 524, 1581, 28, 509, 105, 963],
#  [23, 5],
#  [23, 5, 60],
#  [23, 5, 60, 314],
#  [23, 5, 60, 314, 1582],
#  [23, 5, 60, 314, 1582, 187],
#  [23, 5, 60, 314, 1582, 187, 525],
#  [23, 5, 60, 314, 1582, 187, 525, 3],
#  [23, 5, 60, 314, 1582, 187, 525, 3, 363],
#  [23, 5, 60, 314, 1582, 187, 525, 3, 363, 5],
#  [23, 5, 60, 314, 1582, 187, 525, 3, 363, 5, 145],
#  [23, 5, 60, 314, 1582, 187, 525, 3, 363, 5, 145, 48],
#  [23, 5, 60, 314, 1582, 187, 525, 3, 363, 5, 145, 48, 3],
#  [23, 5, 60, 314, 1582, 187, 525, 3, 363, 5, 145, 48, 3, 106],
#  [23, 5, 60, 314, 1582, 187, 525, 3, 363, 5, 145, 48, 3, 106, 964],
#  [23, 5, 60, 314, 1582, 187, 525, 3, 363, 5, 145, 48, 3, 106, 964, 21],
#  [23, 5, 60, 314, 1582, 187, 525, 3, 363, 5, 145, 48, 3, 106, 964, 21, 40],
#  [27, 3],
#  [27, 3, 73],
#  [27, 3, 73, 1],
#  [27, 3, 73, 1, 1583],
#  [27, 3, 73, 1, 1583, 18],
#  [27, 3, 73, 1, 1583, 18, 184],
#  [27, 3, 73, 1, 1583, 18, 184, 86],
#  [27, 3, 73, 1, 1583, 18, 184, 86, 3],
#  [27, 3, 73, 1, 1583, 18, 184, 86, 3, 306],
#  [27, 3, 73, 1, 1583, 18, 184, 86, 3, 306, 186],
#  [27, 3, 73, 1, 1583, 18, 184, 86, 3, 306, 186, 75],
#  [27, 3, 73, 1, 1583, 18, 184, 86, 3, 306, 186, 75, 2],
#  [27, 3, 73, 1, 1583, 18, 184, 86, 3, 306, 186, 75, 2, 664],
#  [27, 3, 73, 1, 1583, 18, 184, 86, 3, 306, 186, 75, 2, 664, 965],
#  [27, 3, 73, 1, 1583, 18, 184, 86, 3, 306, 186, 75, 2, 664, 965, 3],
#  [27, 3, 73, 1, 1583, 18, 184, 86, 3, 306, 186, 75, 2, 664, 965, 3, 69],
#  [27, 3, 73, 1, 1583, 18, 184, 86, 3, 306, 186, 75, 2, 664, 965, 3, 69, 420],
#  [27,
#   3,
#   73,
#   1,
#   1583,
#   18,
#   184,
#   86,
#   3,
#   306,
#   186,
#   75,
#   2,
#   664,
#   965,
#   3,
#   69,
#   420,
#   665],
#  [27,
#   3,
#   73,
#   1,
#   1583,
#   18,
#   184,
#   86,
#   3,
#   306,
#   186,
#   75,
#   2,
#   664,
#   965,
#   3,
#   69,
#   420,
#   665,
#   274],
#  [27,
#   3,
#   73,
#   1,
#   1583,
#   18,
#   184,
#   86,
#   3,
#   306,
#   186,
#   75,
#   2,
#   664,
#   965,
#   3,
#   69,
#   420,
#   665,
#   274,
#   75],
#  [27,
#   3,
#   73,
#   1,
#   1583,
#   18,
#   184,
#   86,
#   3,
#   306,
#   186,
#   75,
#   2,
#   664,
#   965,
#   3,
#   69,
#   420,
#   665,
#   274,
#   75,
#   2],
#  [27,
#   3,
#   73,
#   1,
#   1583,
#   18,
#   184,
#   86,
#   3,
#   306,
#   186,
#   75,
#   2,
#   664,
#   965,
#   3,
#   69,
#   420,
#   665,
#   274,
#   75,
#   2,
#   664],
#  [27,
#   3,
#   73,
#   1,
#   1583,
#   18,
#   184,
#   86,
#   3,
#   306,
#   186,
#   75,
#   2,
#   664,
#   965,
#   3,
#   69,
#   420,
#   665,
#   274,
#   75,
#   2,
#   664,
#   965],
#  [27,
#   3,
#   73,
#   1,
#   1583,
#   18,
#   184,
#   86,
#   3,
#   306,
#   186,
#   75,
#   2,
#   664,
#   965,
#   3,
#   69,
#   420,
#   665,
#   274,
#   75,
#   2,
#   664,
#   965,
#   113],
#  [427, 3],
#  [427, 3, 966],
#  [427, 3, 966, 31],
#  [427, 3, 966, 31, 146],
#  [427, 3, 966, 31, 146, 7],
#  [427, 3, 966, 31, 146, 7, 526],
#  [427, 3, 966, 31, 146, 7, 526, 4],
#  [427, 3, 966, 31, 146, 7, 526, 4, 527],
#  [427, 3, 966, 31, 146, 7, 526, 4, 527, 9],
#  [427, 3, 966, 31, 146, 7, 526, 4, 527, 9, 17],
#  [427, 3, 966, 31, 146, 7, 526, 4, 527, 9, 17, 8],
#  [427, 3, 966, 31, 146, 7, 526, 4, 527, 9, 17, 8, 967],
#  [1584, 50],
#  [1584, 50, 1585],
#  [1584, 50, 1585, 315],
#  [1584, 50, 1585, 315, 88],
#  [1584, 50, 1585, 315, 88, 18],
#  [1584, 50, 1585, 315, 88, 18, 364],
#  [1584, 50, 1585, 315, 88, 18, 364, 239],
#  [1584, 50, 1585, 315, 88, 18, 364, 239, 1586],
#  [1584, 50, 1585, 315, 88, 18, 364, 239, 1586, 528],
#  [1584, 50, 1585, 315, 88, 18, 364, 239, 1586, 528, 33],
#  [1584, 50, 1585, 315, 88, 18, 364, 239, 1586, 528, 33, 1587],
#  [1584, 50, 1585, 315, 88, 18, 364, 239, 1586, 528, 33, 1587, 97],
#  [1584, 50, 1585, 315, 88, 18, 364, 239, 1586, 528, 33, 1587, 97, 64],
#  [1584, 50, 1585, 315, 88, 18, 364, 239, 1586, 528, 33, 1587, 97, 64, 137],
#  [52, 275],
#  [52, 275, 1588],
#  [52, 275, 1588, 221],
#  [52, 275, 1588, 221, 1589],
#  [52, 275, 1588, 221, 1589, 17],
#  [52, 275, 1588, 221, 1589, 17, 666],
#  [52, 275, 1588, 221, 1589, 17, 666, 42],
#  [52, 275, 1588, 221, 1589, 17, 666, 42, 44],
#  [52, 275, 1588, 221, 1589, 17, 666, 42, 44, 1590],
#  [52, 275, 1588, 221, 1589, 17, 666, 42, 44, 1590, 1591],
#  [52, 275, 1588, 221, 1589, 17, 666, 42, 44, 1590, 1591, 28],
#  [52, 275, 1588, 221, 1589, 17, 666, 42, 44, 1590, 1591, 28, 1592],
#  [52, 275, 1588, 221, 1589, 17, 666, 42, 44, 1590, 1591, 28, 1592, 1593],
#  [52, 275, 1588, 221, 1589, 17, 666, 42, 44, 1590, 1591, 28, 1592, 1593, 7],
#  [52,
#   275,
#   1588,
#   221,
#   1589,
#   17,
#   666,
#   42,
#   44,
#   1590,
#   1591,
#   28,
#   1592,
#   1593,
#   7,
#   1594],
#  [1, 316],
#  [1, 316, 96],
#  [1, 316, 96, 356],
#  [1, 316, 96, 356, 16],
#  [1, 316, 96, 356, 16, 428],
#  [1, 316, 96, 356, 16, 428, 2],
#  [1, 316, 96, 356, 16, 428, 2, 968],
#  [1, 316, 96, 356, 16, 428, 2, 968, 126],
#  [1, 316, 96, 356, 16, 428, 2, 968, 126, 5],
#  [1, 316, 96, 356, 16, 428, 2, 968, 126, 5, 529],
#  [1, 316, 96, 356, 16, 428, 2, 968, 126, 5, 529, 121],
#  [1, 316, 96, 356, 16, 428, 2, 968, 126, 5, 529, 121, 2],
#  [1, 316, 96, 356, 16, 428, 2, 968, 126, 5, 529, 121, 2, 240],
#  [1, 316, 96, 356, 16, 428, 2, 968, 126, 5, 529, 121, 2, 240, 39],
#  [1, 316, 96, 356, 16, 428, 2, 968, 126, 5, 529, 121, 2, 240, 39, 1595],
#  [1, 316, 96, 356, 16, 428, 2, 968, 126, 5, 529, 121, 2, 240, 39, 1595, 16],
#  [1, 316, 96, 356, 16, 428, 2, 968, 126, 5, 529, 121, 2, 240, 39, 1595, 16, 2],
#  [1,
#   316,
#   96,
#   356,
#   16,
#   428,
#   2,
#   968,
#   126,
#   5,
#   529,
#   121,
#   2,
#   240,
#   39,
#   1595,
#   16,
#   2,
#   667],
#  [1,
#   316,
#   96,
#   356,
#   16,
#   428,
#   2,
#   968,
#   126,
#   5,
#   529,
#   121,
#   2,
#   240,
#   39,
#   1595,
#   16,
#   2,
#   667,
#   10],
#  [1,
#   316,
#   96,
#   356,
#   16,
#   428,
#   2,
#   968,
#   126,
#   5,
#   529,
#   121,
#   2,
#   240,
#   39,
#   1595,
#   16,
#   2,
#   667,
#   10,
#   2],
#  [1,
#   316,
#   96,
#   356,
#   16,
#   428,
#   2,
#   968,
#   126,
#   5,
#   529,
#   121,
#   2,
#   240,
#   39,
#   1595,
#   16,
#   2,
#   667,
#   10,
#   2,
#   1596],
#  [51, 668],
#  [51, 668, 147],
#  [51, 668, 147, 18],
#  [51, 668, 147, 18, 1],
#  [51, 668, 147, 18, 1, 669],
#  [51, 668, 147, 18, 1, 669, 1597],
#  [51, 668, 147, 18, 1, 669, 1597, 1],
#  [51, 668, 147, 18, 1, 669, 1597, 1, 1598],
#  [51, 668, 147, 18, 1, 669, 1597, 1, 1598, 1599],
#  [11, 23],
#  [11, 23, 1600],
#  [11, 23, 1600, 48],
#  [11, 23, 1600, 48, 25],
#  [11, 23, 1600, 48, 25, 22],
#  [11, 23, 1600, 48, 25, 22, 1601],
#  [11, 23, 1600, 48, 25, 22, 1601, 1602],
#  [11, 23, 1600, 48, 25, 22, 1601, 1602, 1603],
#  [11, 23, 1600, 48, 25, 22, 1601, 1602, 1603, 969],
#  [11, 23, 1600, 48, 25, 22, 1601, 1602, 1603, 969, 429],
#  [3, 69],
#  [3, 69, 222],
#  [3, 69, 222, 96],
#  [3, 69, 222, 96, 30],
#  [3, 69, 222, 96, 30, 1],
#  [3, 69, 222, 96, 30, 1, 970],
#  [3, 69, 222, 96, 30, 1, 970, 27],
#  [3, 69, 222, 96, 30, 1, 970, 27, 3],
#  [3, 69, 222, 96, 30, 1, 970, 27, 3, 112],
#  [3, 69, 222, 96, 30, 1, 970, 27, 3, 112, 41],
#  [3, 69, 222, 96, 30, 1, 970, 27, 3, 112, 41, 1604],
#  [20, 23],
#  [20, 23, 2],
#  [20, 23, 2, 1605],
#  [20, 23, 2, 1605, 147],
#  [20, 23, 2, 1605, 147, 44],
#  [20, 23, 2, 1605, 147, 44, 971],
#  [20, 23, 2, 1605, 147, 44, 971, 1606],
#  [20, 23, 2, 1605, 147, 44, 971, 1606, 32],
#  [20, 23, 2, 1605, 147, 44, 971, 1606, 32, 9],
#  [20, 23, 2, 1605, 147, 44, 971, 1606, 32, 9, 530],
#  [20, 23, 2, 1605, 147, 44, 971, 1606, 32, 9, 530, 317],
#  [20, 23, 2, 1605, 147, 44, 971, 1606, 32, 9, 530, 317, 37],
#  [20, 23, 2, 1605, 147, 44, 971, 1606, 32, 9, 530, 317, 37, 10],
#  [20, 23, 2, 1605, 147, 44, 971, 1606, 32, 9, 530, 317, 37, 10, 2],
#  [20, 23, 2, 1605, 147, 44, 971, 1606, 32, 9, 530, 317, 37, 10, 2, 1607],
#  [20, 23, 2, 1605, 147, 44, 971, 1606, 32, 9, 530, 317, 37, 10, 2, 1607, 8],
#  [20,
#   23,
#   2,
#   1605,
#   147,
#   44,
#   971,
#   1606,
#   32,
#   9,
#   530,
#   317,
#   37,
#   10,
#   2,
#   1607,
#   8,
#   165],
#  [20,
#   23,
#   2,
#   1605,
#   147,
#   44,
#   971,
#   1606,
#   32,
#   9,
#   530,
#   317,
#   37,
#   10,
#   2,
#   1607,
#   8,
#   165,
#   107],
#  [20,
#   23,
#   2,
#   1605,
#   147,
#   44,
#   971,
#   1606,
#   32,
#   9,
#   530,
#   317,
#   37,
#   10,
#   2,
#   1607,
#   8,
#   165,
#   107,
#   25],
#  [20,
#   23,
#   2,
#   1605,
#   147,
#   44,
#   971,
#   1606,
#   32,
#   9,
#   530,
#   317,
#   37,
#   10,
#   2,
#   1607,
#   8,
#   165,
#   107,
#   25,
#   318],
#  [365, 12],
#  [365, 12, 97],
#  [365, 12, 97, 88],
#  [365, 12, 97, 88, 153],
#  [365, 12, 97, 88, 153, 84],
#  [365, 12, 97, 88, 153, 84, 972],
#  [365, 12, 97, 88, 153, 84, 972, 34],
#  [365, 12, 97, 88, 153, 84, 972, 34, 46],
#  [365, 12, 97, 88, 153, 84, 972, 34, 46, 10],
#  [365, 12, 97, 88, 153, 84, 972, 34, 46, 10, 138],
#  [365, 12, 97, 88, 153, 84, 972, 34, 46, 10, 138, 973],
#  [1608, 28],
#  [1608, 28, 366],
#  [1608, 28, 366, 974],
#  [1608, 28, 366, 974, 28],
#  [1608, 28, 366, 974, 28, 531],
#  [1608, 28, 366, 974, 28, 531, 1609],
#  [1608, 28, 366, 974, 28, 531, 1609, 27],
#  [1608, 28, 366, 974, 28, 531, 1609, 27, 9],
#  [1608, 28, 366, 974, 28, 531, 1609, 27, 9, 532],
#  [1608, 28, 366, 974, 28, 531, 1609, 27, 9, 532, 18],
#  [1608, 28, 366, 974, 28, 531, 1609, 27, 9, 532, 18, 367],
#  [1608, 28, 366, 974, 28, 531, 1609, 27, 9, 532, 18, 367, 1610],
#  [1608, 28, 366, 974, 28, 531, 1609, 27, 9, 532, 18, 367, 1610, 46],
#  [1608, 28, 366, 974, 28, 531, 1609, 27, 9, 532, 18, 367, 1610, 46, 33],
#  [1608, 28, 366, 974, 28, 531, 1609, 27, 9, 532, 18, 367, 1610, 46, 33, 319],
#  [8, 78],
#  [8, 78, 7],
#  [8, 78, 7, 3],
#  [8, 78, 7, 3, 28],
#  [8, 78, 7, 3, 28, 58],
#  [8, 78, 7, 3, 28, 58, 533],
#  [8, 78, 7, 3, 28, 58, 533, 534],
#  [8, 78, 7, 3, 28, 58, 533, 534, 430],
#  [8, 78, 7, 3, 28, 58, 533, 534, 430, 52],
#  [8, 78, 7, 3, 28, 58, 533, 534, 430, 52, 670],
#  [8, 78, 7, 3, 28, 58, 533, 534, 430, 52, 670, 7],
#  [8, 78, 7, 3, 28, 58, 533, 534, 430, 52, 670, 7, 3],
#  [8, 78, 7, 3, 28, 58, 533, 534, 430, 52, 670, 7, 3, 1611],
#  [199, 29],
#  [199, 29, 92],
#  [199, 29, 92, 1612],
#  [199, 29, 92, 1612, 53],
#  [199, 29, 92, 1612, 53, 9],
#  [199, 29, 92, 1612, 53, 9, 79],
#  [199, 29, 92, 1612, 53, 9, 79, 4],
#  [199, 29, 92, 1612, 53, 9, 79, 4, 166],
#  [199, 29, 92, 1612, 53, 9, 79, 4, 166, 1],
#  [199, 29, 92, 1612, 53, 9, 79, 4, 166, 1, 368],
#  [199, 29, 92, 1612, 53, 9, 79, 4, 166, 1, 368, 1],
#  [199, 29, 92, 1612, 53, 9, 79, 4, 166, 1, 368, 1, 368],
#  [199, 29, 92, 1612, 53, 9, 79, 4, 166, 1, 368, 1, 368, 11],
#  [199, 29, 92, 1612, 53, 9, 79, 4, 166, 1, 368, 1, 368, 11, 368],
#  [22, 320],
#  [22, 320, 19],
#  [22, 320, 19, 223],
#  [22, 320, 19, 223, 41],
#  [22, 320, 19, 223, 41, 318],
#  [22, 320, 19, 223, 41, 318, 42],
#  [22, 320, 19, 223, 41, 318, 42, 22],
#  [22, 320, 19, 223, 41, 318, 42, 22, 431],
#  [22, 320, 19, 223, 41, 318, 42, 22, 431, 320],
#  [22, 320, 19, 223, 41, 318, 42, 22, 431, 320, 19],
#  [22, 320, 19, 223, 41, 318, 42, 22, 431, 320, 19, 432],
#  [22, 320, 19, 223, 41, 318, 42, 22, 431, 320, 19, 432, 2],
#  [22, 320, 19, 223, 41, 318, 42, 22, 431, 320, 19, 432, 2, 1613],
#  [22, 320, 19, 223, 41, 318, 42, 22, 431, 320, 19, 432, 2, 1613, 38],
#  [22, 320, 19, 223, 41, 318, 42, 22, 431, 320, 19, 432, 2, 1613, 38, 321],
#  [22, 320, 19, 223, 41, 318, 42, 22, 431, 320, 19, 432, 2, 1613, 38, 321, 369],
#  [22,
#   320,
#   19,
#   223,
#   41,
#   318,
#   42,
#   22,
#   431,
#   320,
#   19,
#   432,
#   2,
#   1613,
#   38,
#   321,
#   369,
#   179],
#  [22,
#   320,
#   19,
#   223,
#   41,
#   318,
#   42,
#   22,
#   431,
#   320,
#   19,
#   432,
#   2,
#   1613,
#   38,
#   321,
#   369,
#   179,
#   16],
#  [22,
#   320,
#   19,
#   223,
#   41,
#   318,
#   42,
#   22,
#   431,
#   320,
#   19,
#   432,
#   2,
#   1613,
#   38,
#   321,
#   369,
#   179,
#   16,
#   1],
#  [22,
#   320,
#   19,
#   223,
#   41,
#   318,
#   42,
#   22,
#   431,
#   320,
#   19,
#   432,
#   2,
#   1613,
#   38,
#   321,
#   369,
#   179,
#   16,
#   1,
#   671],
#  [22,
#   320,
#   19,
#   223,
#   41,
#   318,
#   42,
#   22,
#   431,
#   320,
#   19,
#   432,
#   2,
#   1613,
#   38,
#   321,
#   369,
#   179,
#   16,
#   1,
#   671,
#   45],
#  [22,
#   320,
#   19,
#   223,
#   41,
#   318,
#   42,
#   22,
#   431,
#   320,
#   19,
#   432,
#   2,
#   1613,
#   38,
#   321,
#   369,
#   179,
#   16,
#   1,
#   671,
#   45,
#   672],
#  [22,
#   320,
#   19,
#   223,
#   41,
#   318,
#   42,
#   22,
#   431,
#   320,
#   19,
#   432,
#   2,
#   1613,
#   38,
#   321,
#   369,
#   179,
#   16,
#   1,
#   671,
#   45,
#   672,
#   8],
#  [22,
#   320,
#   19,
#   223,
#   41,
#   318,
#   42,
#   22,
#   431,
#   320,
#   19,
#   432,
#   2,
#   1613,
#   38,
#   321,
#   369,
#   179,
#   16,
#   1,
#   671,
#   45,
#   672,
#   8,
#   1614],
#  [22,
#   320,
#   19,
#   223,
#   41,
#   318,
#   42,
#   22,
#   431,
#   320,
#   19,
#   432,
#   2,
#   1613,
#   38,
#   321,
#   369,
#   179,
#   16,
#   1,
#   671,
#   45,
#   672,
#   8,
#   1614,
#   1615],
#  [1616, 1617],
#  [1616, 1617, 8],
#  [1616, 1617, 8, 1618],
#  [1616, 1617, 8, 1618, 114],
#  [1616, 1617, 8, 1618, 114, 74],
#  [1616, 1617, 8, 1618, 114, 74, 673],
#  [1616, 1617, 8, 1618, 114, 74, 673, 154],
#  [1616, 1617, 8, 1618, 114, 74, 673, 154, 17],
#  [1616, 1617, 8, 1618, 114, 74, 673, 154, 17, 14],
#  [1616, 1617, 8, 1618, 114, 74, 673, 154, 17, 14, 32],
#  [1616, 1617, 8, 1618, 114, 74, 673, 154, 17, 14, 32, 3],
#  [1616, 1617, 8, 1618, 114, 74, 673, 154, 17, 14, 32, 3, 370],
#  [1616, 1617, 8, 1618, 114, 74, 673, 154, 17, 14, 32, 3, 370, 200],
#  [1616, 1617, 8, 1618, 114, 74, 673, 154, 17, 14, 32, 3, 370, 200, 2],
#  [1616, 1617, 8, 1618, 114, 74, 673, 154, 17, 14, 32, 3, 370, 200, 2, 674],
#  [1, 535],
#  [1, 535, 12],
#  [1, 535, 12, 30],
#  [1, 535, 12, 30, 24],
#  [1, 535, 12, 30, 24, 975],
#  [1, 535, 12, 30, 24, 975, 322],
#  [1, 535, 12, 30, 24, 975, 322, 1619],
#  [1, 535, 12, 30, 24, 975, 322, 1619, 433],
#  [1, 535, 12, 30, 24, 975, 322, 1619, 433, 52],
#  [1, 535, 12, 30, 24, 975, 322, 1619, 433, 52, 241],
#  [1, 535, 12, 30, 24, 975, 322, 1619, 433, 52, 241, 433],
#  [1, 535, 12, 30, 24, 975, 322, 1619, 433, 52, 241, 433, 1],
#  [1, 535, 12, 30, 24, 975, 322, 1619, 433, 52, 241, 433, 1, 675],
#  [1, 535, 12, 30, 24, 975, 322, 1619, 433, 52, 241, 433, 1, 675, 323],
#  [1, 535, 12, 30, 24, 975, 322, 1619, 433, 52, 241, 433, 1, 675, 323, 7],
#  [1, 535, 12, 30, 24, 975, 322, 1619, 433, 52, 241, 433, 1, 675, 323, 7, 676],
#  [1,
#   535,
#   12,
#   30,
#   24,
#   975,
#   322,
#   1619,
#   433,
#   52,
#   241,
#   433,
#   1,
#   675,
#   323,
#   7,
#   676,
#   7],
#  [1,
#   535,
#   12,
#   30,
#   24,
#   975,
#   322,
#   1619,
#   433,
#   52,
#   241,
#   433,
#   1,
#   675,
#   323,
#   7,
#   676,
#   7,
#   1620],
#  [1,
#   535,
#   12,
#   30,
#   24,
#   975,
#   322,
#   1619,
#   433,
#   52,
#   241,
#   433,
#   1,
#   675,
#   323,
#   7,
#   676,
#   7,
#   1620,
#   6],
#  [1,
#   535,
#   12,
#   30,
#   24,
#   975,
#   322,
#   1619,
#   433,
#   52,
#   241,
#   433,
#   1,
#   675,
#   323,
#   7,
#   676,
#   7,
#   1620,
#   6,
#   46],
#  [1,
#   535,
#   12,
#   30,
#   24,
#   975,
#   322,
#   1619,
#   433,
#   52,
#   241,
#   433,
#   1,
#   675,
#   323,
#   7,
#   676,
#   7,
#   1620,
#   6,
#   46,
#   28],
#  [1,
#   535,
#   12,
#   30,
#   24,
#   975,
#   322,
#   1619,
#   433,
#   52,
#   241,
#   433,
#   1,
#   675,
#   323,
#   7,
#   676,
#   7,
#   1620,
#   6,
#   46,
#   28,
#   976],
#  [1,
#   535,
#   12,
#   30,
#   24,
#   975,
#   322,
#   1619,
#   433,
#   52,
#   241,
#   433,
#   1,
#   675,
#   323,
#   7,
#   676,
#   7,
#   1620,
#   6,
#   46,
#   28,
#   976,
#   3],
#  [1,
#   535,
#   12,
#   30,
#   24,
#   975,
#   322,
#   1619,
#   433,
#   52,
#   241,
#   433,
#   1,
#   675,
#   323,
#   7,
#   676,
#   7,
#   1620,
#   6,
#   46,
#   28,
#   976,
#   3,
#   1621],
#  [1,
#   535,
#   12,
#   30,
#   24,
#   975,
#   322,
#   1619,
#   433,
#   52,
#   241,
#   433,
#   1,
#   675,
#   323,
#   7,
#   676,
#   7,
#   1620,
#   6,
#   46,
#   28,
#   976,
#   3,
#   1621,
#   7],
#  [1,
#   535,
#   12,
#   30,
#   24,
#   975,
#   322,
#   1619,
#   433,
#   52,
#   241,
#   433,
#   1,
#   675,
#   323,
#   7,
#   676,
#   7,
#   1620,
#   6,
#   46,
#   28,
#   976,
#   3,
#   1621,
#   7,
#   1622],
#  [25, 3],
#  [25, 3, 91],
#  [25, 3, 91, 57],
#  [25, 3, 91, 57, 3],
#  [25, 3, 91, 57, 3, 43],
#  [25, 3, 91, 57, 3, 43, 434],
#  [25, 3, 91, 57, 3, 43, 434, 536],
#  [25, 3, 91, 57, 3, 43, 434, 536, 4],
#  [25, 3, 91, 57, 3, 43, 434, 536, 4, 34],
#  [25, 3, 91, 57, 3, 43, 434, 536, 4, 34, 37],
#  [25, 3, 91, 57, 3, 43, 434, 536, 4, 34, 37, 10],
#  [25, 3, 91, 57, 3, 43, 434, 536, 4, 34, 37, 10, 1],
#  [25, 3, 91, 57, 3, 43, 434, 536, 4, 34, 37, 10, 1, 977],
#  [25, 3, 91, 57, 3, 43, 434, 536, 4, 34, 37, 10, 1, 977, 3],
#  [25, 3, 91, 57, 3, 43, 434, 536, 4, 34, 37, 10, 1, 977, 3, 1623],
#  [25, 3, 91, 57, 3, 43, 434, 536, 4, 34, 37, 10, 1, 977, 3, 1623, 677],
#  [25, 3, 91, 57, 3, 43, 434, 536, 4, 34, 37, 10, 1, 977, 3, 1623, 677, 2],
#  [25, 3, 91, 57, 3, 43, 434, 536, 4, 34, 37, 10, 1, 977, 3, 1623, 677, 2, 242],
#  [25,
#   3,
#   91,
#   57,
#   3,
#   43,
#   434,
#   536,
#   4,
#   34,
#   37,
#   10,
#   1,
#   977,
#   3,
#   1623,
#   677,
#   2,
#   242,
#   1624],
#  [25,
#   3,
#   91,
#   57,
#   3,
#   43,
#   434,
#   536,
#   4,
#   34,
#   37,
#   10,
#   1,
#   977,
#   3,
#   1623,
#   677,
#   2,
#   242,
#   1624,
#   39],
#  [25,
#   3,
#   91,
#   57,
#   3,
#   43,
#   434,
#   536,
#   4,
#   34,
#   37,
#   10,
#   1,
#   977,
#   3,
#   1623,
#   677,
#   2,
#   242,
#   1624,
#   39,
#   4],
#  [25,
#   3,
#   91,
#   57,
#   3,
#   43,
#   434,
#   536,
#   4,
#   34,
#   37,
#   10,
#   1,
#   977,
#   3,
#   1623,
#   677,
#   2,
#   242,
#   1624,
#   39,
#   4,
#   537],
#  [25,
#   3,
#   91,
#   57,
#   3,
#   43,
#   434,
#   536,
#   4,
#   34,
#   37,
#   10,
#   1,
#   977,
#   3,
#   1623,
#   677,
#   2,
#   242,
#   1624,
#   39,
#   4,
#   537,
#   9],
#  [25,
#   3,
#   91,
#   57,
#   3,
#   43,
#   434,
#   536,
#   4,
#   34,
#   37,
#   10,
#   1,
#   977,
#   3,
#   1623,
#   677,
#   2,
#   242,
#   1624,
#   39,
#   4,
#   537,
#   9,
#   198],
#  [20, 23],
#  [20, 23, 2],
#  [20, 23, 2, 678],
#  [20, 23, 2, 678, 34],
#  [20, 23, 2, 678, 34, 1],
#  [20, 23, 2, 678, 34, 1, 217],
#  [20, 23, 2, 678, 34, 1, 217, 17],
#  [20, 23, 2, 678, 34, 1, 217, 17, 1625],
#  [20, 23, 2, 678, 34, 1, 217, 17, 1625, 1626],
#  [20, 23, 2, 678, 34, 1, 217, 17, 1625, 1626, 32],
#  [20, 23, 2, 678, 34, 1, 217, 17, 1625, 1626, 32, 52],
#  [20, 23, 2, 678, 34, 1, 217, 17, 1625, 1626, 32, 52, 1627],
#  [20, 23, 2, 678, 34, 1, 217, 17, 1625, 1626, 32, 52, 1627, 4],
#  [20, 23, 2, 678, 34, 1, 217, 17, 1625, 1626, 32, 52, 1627, 4, 538],
#  [20, 23, 2, 678, 34, 1, 217, 17, 1625, 1626, 32, 52, 1627, 4, 538, 539],
#  [11, 15],
#  [11, 15, 1628],
#  [11, 15, 1628, 435],
#  [11, 15, 1628, 435, 1629],
#  [11, 15, 1628, 435, 1629, 978],
#  [11, 15, 1628, 435, 1629, 978, 1630],
#  [3, 39],
#  [3, 39, 979],
#  [3, 39, 979, 1631],
#  [3, 39, 979, 1631, 17],
#  [3, 39, 979, 1631, 17, 1],
#  [3, 39, 979, 1631, 17, 1, 115],
#  [3, 39, 979, 1631, 17, 1, 115, 49],
#  [3, 39, 979, 1631, 17, 1, 115, 49, 361],
#  [3, 39, 979, 1631, 17, 1, 115, 49, 361, 21],
#  [3, 39, 979, 1631, 17, 1, 115, 49, 361, 21, 1632],
#  [3, 39, 979, 1631, 17, 1, 115, 49, 361, 21, 1632, 980],
#  [3, 39, 979, 1631, 17, 1, 115, 49, 361, 21, 1632, 980, 56],
#  [3, 39, 979, 1631, 17, 1, 115, 49, 361, 21, 1632, 980, 56, 1633],
#  [3, 39, 979, 1631, 17, 1, 115, 49, 361, 21, 1632, 980, 56, 1633, 1634],
#  [3, 39, 979, 1631, 17, 1, 115, 49, 361, 21, 1632, 980, 56, 1633, 1634, 15],
#  [3,
#   39,
#   979,
#   1631,
#   17,
#   1,
#   115,
#   49,
#   361,
#   21,
#   1632,
#   980,
#   56,
#   1633,
#   1634,
#   15,
#   188],
#  [3,
#   39,
#   979,
#   1631,
#   17,
#   1,
#   115,
#   49,
#   361,
#   21,
#   1632,
#   980,
#   56,
#   1633,
#   1634,
#   15,
#   188,
#   167],
#  [3,
#   39,
#   979,
#   1631,
#   17,
#   1,
#   115,
#   49,
#   361,
#   21,
#   1632,
#   980,
#   56,
#   1633,
#   1634,
#   15,
#   188,
#   167,
#   126],
#  [3,
#   39,
#   979,
#   1631,
#   17,
#   1,
#   115,
#   49,
#   361,
#   21,
#   1632,
#   980,
#   56,
#   1633,
#   1634,
#   15,
#   188,
#   167,
#   126,
#   44],
#  [3,
#   39,
#   979,
#   1631,
#   17,
#   1,
#   115,
#   49,
#   361,
#   21,
#   1632,
#   980,
#   56,
#   1633,
#   1634,
#   15,
#   188,
#   167,
#   126,
#   44,
#   980],
#  [3,
#   39,
#   979,
#   1631,
#   17,
#   1,
#   115,
#   49,
#   361,
#   21,
#   1632,
#   980,
#   56,
#   1633,
#   1634,
#   15,
#   188,
#   167,
#   126,
#   44,
#   980,
#   56],
#  [3,
#   39,
#   979,
#   1631,
#   17,
#   1,
#   115,
#   49,
#   361,
#   21,
#   1632,
#   980,
#   56,
#   1633,
#   1634,
#   15,
#   188,
#   167,
#   126,
#   44,
#   980,
#   56,
#   1635],
#  [3,
#   39,
#   979,
#   1631,
#   17,
#   1,
#   115,
#   49,
#   361,
#   21,
#   1632,
#   980,
#   56,
#   1633,
#   1634,
#   15,
#   188,
#   167,
#   126,
#   44,
#   980,
#   56,
#   1635,
#   1636],
#  [3,
#   39,
#   979,
#   1631,
#   17,
#   1,
#   115,
#   49,
#   361,
#   21,
#   1632,
#   980,
#   56,
#   1633,
#   1634,
#   15,
#   188,
#   167,
#   126,
#   44,
#   980,
#   56,
#   1635,
#   1636,
#   3],
#  [3,
#   39,
#   979,
#   1631,
#   17,
#   1,
#   115,
#   49,
#   361,
#   21,
#   1632,
#   980,
#   56,
#   1633,
#   1634,
#   15,
#   188,
#   167,
#   126,
#   44,
#   980,
#   56,
#   1635,
#   1636,
#   3,
#   363],
#  [3,
#   39,
#   979,
#   1631,
#   17,
#   1,
#   115,
#   49,
#   361,
#   21,
#   1632,
#   980,
#   56,
#   1633,
#   1634,
#   15,
#   188,
#   167,
#   126,
#   44,
#   980,
#   56,
#   1635,
#   1636,
#   3,
#   363,
#   4],
#  [3,
#   39,
#   979,
#   1631,
#   17,
#   1,
#   115,
#   49,
#   361,
#   21,
#   1632,
#   980,
#   56,
#   1633,
#   1634,
#   15,
#   188,
#   167,
#   126,
#   44,
#   980,
#   56,
#   1635,
#   1636,
#   3,
#   363,
#   4,
#   1637],
#  [3,
#   39,
#   979,
#   1631,
#   17,
#   1,
#   115,
#   49,
#   361,
#   21,
#   1632,
#   980,
#   56,
#   1633,
#   1634,
#   15,
#   188,
#   167,
#   126,
#   44,
#   980,
#   56,
#   1635,
#   1636,
#   3,
#   363,
#   4,
#   1637,
#   1638],
#  [3, 152],
#  [3, 152, 8],
#  [3, 152, 8, 540],
#  [3, 152, 8, 540, 71],
#  [3, 152, 8, 540, 71, 529],
#  [3, 152, 8, 540, 71, 529, 33],
#  [3, 152, 8, 540, 71, 529, 33, 201],
#  [3, 152, 8, 540, 71, 529, 33, 201, 1],
#  [3, 152, 8, 540, 71, 529, 33, 201, 1, 1639],
#  [3, 152, 8, 540, 71, 529, 33, 201, 1, 1639, 7],
#  [3, 152, 8, 540, 71, 529, 33, 201, 1, 1639, 7, 52],
#  [3, 152, 8, 540, 71, 529, 33, 201, 1, 1639, 7, 52, 155],
#  [3, 152, 8, 540, 71, 529, 33, 201, 1, 1639, 7, 52, 155, 18],
#  [3, 152, 8, 540, 71, 529, 33, 201, 1, 1639, 7, 52, 155, 18, 40],
#  [3, 152, 8, 540, 71, 529, 33, 201, 1, 1639, 7, 52, 155, 18, 40, 17],
#  [3, 152, 8, 540, 71, 529, 33, 201, 1, 1639, 7, 52, 155, 18, 40, 17, 1640],
#  [3,
#   152,
#   8,
#   540,
#   71,
#   529,
#   33,
#   201,
#   1,
#   1639,
#   7,
#   52,
#   155,
#   18,
#   40,
#   17,
#   1640,
#   1641],
#  [3, 541],
#  [3, 541, 139],
#  [3, 541, 139, 981],
#  [3, 541, 139, 981, 62],
#  [3, 541, 139, 981, 62, 1],
#  [3, 541, 139, 981, 62, 1, 679],
#  [3, 541, 139, 981, 62, 1, 679, 982],
#  [3, 541, 139, 981, 62, 1, 679, 982, 3],
#  [3, 541, 139, 981, 62, 1, 679, 982, 3, 43],
#  [3, 541, 139, 981, 62, 1, 679, 982, 3, 43, 60],
#  [3, 541, 139, 981, 62, 1, 679, 982, 3, 43, 60, 11],
#  [3, 541, 139, 981, 62, 1, 679, 982, 3, 43, 60, 11, 22],
#  [3, 541, 139, 981, 62, 1, 679, 982, 3, 43, 60, 11, 22, 983],
#  [3, 541, 139, 981, 62, 1, 679, 982, 3, 43, 60, 11, 22, 983, 89],
#  [3, 541, 139, 981, 62, 1, 679, 982, 3, 43, 60, 11, 22, 983, 89, 17],
#  [3, 541, 139, 981, 62, 1, 679, 982, 3, 43, 60, 11, 22, 983, 89, 17, 42],
#  [3, 541, 139, 981, 62, 1, 679, 982, 3, 43, 60, 11, 22, 983, 89, 17, 42, 3],
#  [3,
#   541,
#   139,
#   981,
#   62,
#   1,
#   679,
#   982,
#   3,
#   43,
#   60,
#   11,
#   22,
#   983,
#   89,
#   17,
#   42,
#   3,
#   19],
#  [3,
#   541,
#   139,
#   981,
#   62,
#   1,
#   679,
#   982,
#   3,
#   43,
#   60,
#   11,
#   22,
#   983,
#   89,
#   17,
#   42,
#   3,
#   19,
#   148],
#  [3,
#   541,
#   139,
#   981,
#   62,
#   1,
#   679,
#   982,
#   3,
#   43,
#   60,
#   11,
#   22,
#   983,
#   89,
#   17,
#   42,
#   3,
#   19,
#   148,
#   984],
#  [3,
#   541,
#   139,
#   981,
#   62,
#   1,
#   679,
#   982,
#   3,
#   43,
#   60,
#   11,
#   22,
#   983,
#   89,
#   17,
#   42,
#   3,
#   19,
#   148,
#   984,
#   46],
#  [3,
#   541,
#   139,
#   981,
#   62,
#   1,
#   679,
#   982,
#   3,
#   43,
#   60,
#   11,
#   22,
#   983,
#   89,
#   17,
#   42,
#   3,
#   19,
#   148,
#   984,
#   46,
#   80],
#  [3,
#   541,
#   139,
#   981,
#   62,
#   1,
#   679,
#   982,
#   3,
#   43,
#   60,
#   11,
#   22,
#   983,
#   89,
#   17,
#   42,
#   3,
#   19,
#   148,
#   984,
#   46,
#   80,
#   8],
#  [3,
#   541,
#   139,
#   981,
#   62,
#   1,
#   679,
#   982,
#   3,
#   43,
#   60,
#   11,
#   22,
#   983,
#   89,
#   17,
#   42,
#   3,
#   19,
#   148,
#   984,
#   46,
#   80,
#   8,
#   680],
#  [3,
#   541,
#   139,
#   981,
#   62,
#   1,
#   679,
#   982,
#   3,
#   43,
#   60,
#   11,
#   22,
#   983,
#   89,
#   17,
#   42,
#   3,
#   19,
#   148,
#   984,
#   46,
#   80,
#   8,
#   680,
#   119],
#  [3,
#   541,
#   139,
#   981,
#   62,
#   1,
#   679,
#   982,
#   3,
#   43,
#   60,
#   11,
#   22,
#   983,
#   89,
#   17,
#   42,
#   3,
#   19,
#   148,
#   984,
#   46,
#   80,
#   8,
#   680,
#   119,
#   152],
#  [3,
#   541,
#   139,
#   981,
#   62,
#   1,
#   679,
#   982,
#   3,
#   43,
#   60,
#   11,
#   22,
#   983,
#   89,
#   17,
#   42,
#   3,
#   19,
#   148,
#   984,
#   46,
#   80,
#   8,
#   680,
#   119,
#   152,
#   14],
#  [3,
#   541,
#   139,
#   981,
#   62,
#   1,
#   679,
#   982,
#   3,
#   43,
#   60,
#   11,
#   22,
#   983,
#   89,
#   17,
#   42,
#   3,
#   19,
#   148,
#   984,
#   46,
#   80,
#   8,
#   680,
#   119,
#   152,
#   14,
#   55],
#  [3,
#   541,
#   139,
#   981,
#   62,
#   1,
#   679,
#   982,
#   3,
#   43,
#   60,
#   11,
#   22,
#   983,
#   89,
#   17,
#   42,
#   3,
#   19,
#   148,
#   984,
#   46,
#   80,
#   8,
#   680,
#   119,
#   152,
#   14,
#   55,
#   40],
#  [11, 307],
#  [11, 307, 10],
#  [11, 307, 10, 985],
#  [11, 307, 10, 985, 13],
#  [11, 307, 10, 985, 13, 1642],
#  [11, 307, 10, 985, 13, 1642, 30],
#  [11, 307, 10, 985, 13, 1642, 30, 1643],
#  [20, 53],
#  [20, 53, 371],
#  [20, 53, 371, 269],
#  [20, 53, 371, 269, 156],
#  [20, 53, 371, 269, 156, 4],
#  [20, 53, 371, 269, 156, 4, 19],
#  [20, 53, 371, 269, 156, 4, 19, 87],
#  [20, 53, 371, 269, 156, 4, 19, 87, 17],
#  [20, 53, 371, 269, 156, 4, 19, 87, 17, 372],
#  [20, 53, 371, 269, 156, 4, 19, 87, 17, 372, 269],
#  [20, 53, 371, 269, 156, 4, 19, 87, 17, 372, 269, 101],
#  [20, 53, 371, 269, 156, 4, 19, 87, 17, 372, 269, 101, 160],
#  [20, 53, 371, 269, 156, 4, 19, 87, 17, 372, 269, 101, 160, 6],
#  [20, 53, 371, 269, 156, 4, 19, 87, 17, 372, 269, 101, 160, 6, 2],
#  [20, 53, 371, 269, 156, 4, 19, 87, 17, 372, 269, 101, 160, 6, 2, 239],
#  [20, 53, 371, 269, 156, 4, 19, 87, 17, 372, 269, 101, 160, 6, 2, 239, 52],
#  [20,
#   53,
#   371,
#   269,
#   156,
#   4,
#   19,
#   87,
#   17,
#   372,
#   269,
#   101,
#   160,
#   6,
#   2,
#   239,
#   52,
#   309],
#  [20,
#   53,
#   371,
#   269,
#   156,
#   4,
#   19,
#   87,
#   17,
#   372,
#   269,
#   101,
#   160,
#   6,
#   2,
#   239,
#   52,
#   309,
#   4],
#  [20,
#   53,
#   371,
#   269,
#   156,
#   4,
#   19,
#   87,
#   17,
#   372,
#   269,
#   101,
#   160,
#   6,
#   2,
#   239,
#   52,
#   309,
#   4,
#   33],
#  [20,
#   53,
#   371,
#   269,
#   156,
#   4,
#   19,
#   87,
#   17,
#   372,
#   269,
#   101,
#   160,
#   6,
#   2,
#   239,
#   52,
#   309,
#   4,
#   33,
#   2],
#  [20,
#   53,
#   371,
#   269,
#   156,
#   4,
#   19,
#   87,
#   17,
#   372,
#   269,
#   101,
#   160,
#   6,
#   2,
#   239,
#   52,
#   309,
#   4,
#   33,
#   2,
#   101],
#  [20,
#   53,
#   371,
#   269,
#   156,
#   4,
#   19,
#   87,
#   17,
#   372,
#   269,
#   101,
#   160,
#   6,
#   2,
#   239,
#   52,
#   309,
#   4,
#   33,
#   2,
#   101,
#   324],
#  [46, 1644],
#  [46, 1644, 1645],
#  [46, 1644, 1645, 28],
#  [46, 1644, 1645, 28, 168],
#  [46, 1644, 1645, 28, 168, 681],
#  [46, 1644, 1645, 28, 168, 681, 542],
#  [46, 1644, 1645, 28, 168, 681, 542, 25],
#  [46, 1644, 1645, 28, 168, 681, 542, 25, 5],
#  [46, 1644, 1645, 28, 168, 681, 542, 25, 5, 19],
#  [46, 1644, 1645, 28, 168, 681, 542, 25, 5, 19, 1],
#  [46, 1644, 1645, 28, 168, 681, 542, 25, 5, 19, 1, 1646],
#  [11, 23],
#  [11, 23, 2],
#  [11, 23, 2, 373],
#  [11, 23, 2, 373, 10],
#  [11, 23, 2, 373, 10, 1647],
#  [11, 23, 2, 373, 10, 1647, 986],
#  [11, 23, 2, 373, 10, 1647, 986, 48],
#  [11, 23, 2, 373, 10, 1647, 986, 48, 25],
#  [11, 23, 2, 373, 10, 1647, 986, 48, 25, 26],
#  [11, 23, 2, 373, 10, 1647, 986, 48, 25, 26, 112],
#  [11, 23, 2, 373, 10, 1647, 986, 48, 25, 26, 112, 987],
#  [11, 23, 2, 373, 10, 1647, 986, 48, 25, 26, 112, 987, 988],
#  [99, 374],
#  [99, 374, 543],
#  [99, 374, 543, 66],
#  [99, 374, 543, 66, 202],
#  [99, 374, 543, 66, 202, 4],
#  [99, 374, 543, 66, 202, 4, 436],
#  [99, 374, 543, 66, 202, 4, 436, 5],
#  [99, 374, 543, 66, 202, 4, 436, 5, 14],
#  [99, 374, 543, 66, 202, 4, 436, 5, 14, 66],
#  [99, 374, 543, 66, 202, 4, 436, 5, 14, 66, 202],
#  [99, 374, 543, 66, 202, 4, 436, 5, 14, 66, 202, 4],
#  [99, 374, 543, 66, 202, 4, 436, 5, 14, 66, 202, 4, 436],
#  [99, 374, 543, 66, 202, 4, 436, 5, 14, 66, 202, 4, 436, 5],
#  [99, 374, 543, 66, 202, 4, 436, 5, 14, 66, 202, 4, 436, 5, 113],
#  [99, 374, 543, 66, 202, 4, 436, 5, 14, 66, 202, 4, 436, 5, 113, 55],
#  [99, 374, 543, 66, 202, 4, 436, 5, 14, 66, 202, 4, 436, 5, 113, 55, 12],
#  [99, 374, 543, 66, 202, 4, 436, 5, 14, 66, 202, 4, 436, 5, 113, 55, 12, 8],
#  [99,
#   374,
#   543,
#   66,
#   202,
#   4,
#   436,
#   5,
#   14,
#   66,
#   202,
#   4,
#   436,
#   5,
#   113,
#   55,
#   12,
#   8,
#   540],
#  [99,
#   374,
#   543,
#   66,
#   202,
#   4,
#   436,
#   5,
#   14,
#   66,
#   202,
#   4,
#   436,
#   5,
#   113,
#   55,
#   12,
#   8,
#   540,
#   276],
#  [99,
#   374,
#   543,
#   66,
#   202,
#   4,
#   436,
#   5,
#   14,
#   66,
#   202,
#   4,
#   436,
#   5,
#   113,
#   55,
#   12,
#   8,
#   540,
#   276,
#   374],
#  [99,
#   374,
#   543,
#   66,
#   202,
#   4,
#   436,
#   5,
#   14,
#   66,
#   202,
#   4,
#   436,
#   5,
#   113,
#   55,
#   12,
#   8,
#   540,
#   276,
#   374,
#   51],
#  [99,
#   374,
#   543,
#   66,
#   202,
#   4,
#   436,
#   5,
#   14,
#   66,
#   202,
#   4,
#   436,
#   5,
#   113,
#   55,
#   12,
#   8,
#   540,
#   276,
#   374,
#   51,
#   31],
#  [99,
#   374,
#   543,
#   66,
#   202,
#   4,
#   436,
#   5,
#   14,
#   66,
#   202,
#   4,
#   436,
#   5,
#   113,
#   55,
#   12,
#   8,
#   540,
#   276,
#   374,
#   51,
#   31,
#   375],
#  [99,
#   374,
#   543,
#   66,
#   202,
#   4,
#   436,
#   5,
#   14,
#   66,
#   202,
#   4,
#   436,
#   5,
#   113,
#   55,
#   12,
#   8,
#   540,
#   276,
#   374,
#   51,
#   31,
#   375,
#   14],
#  [99,
#   374,
#   543,
#   66,
#   202,
#   4,
#   436,
#   5,
#   14,
#   66,
#   202,
#   4,
#   436,
#   5,
#   113,
#   55,
#   12,
#   8,
#   540,
#   276,
#   374,
#   51,
#   31,
#   375,
#   14,
#   1648],
#  [40, 160],
#  [40, 160, 1649],
#  [40, 160, 1649, 62],
#  [40, 160, 1649, 62, 989],
#  [40, 160, 1649, 62, 989, 185],
#  [40, 160, 1649, 62, 989, 185, 512],
#  [40, 160, 1649, 62, 989, 185, 512, 990],
#  [40, 160, 1649, 62, 989, 185, 512, 990, 219],
#  [40, 160, 1649, 62, 989, 185, 512, 990, 219, 12],
#  [40, 160, 1649, 62, 989, 185, 512, 990, 219, 12, 21],
#  [40, 160, 1649, 62, 989, 185, 512, 990, 219, 12, 21, 27],
#  [40, 160, 1649, 62, 989, 185, 512, 990, 219, 12, 21, 27, 5],
#  [40, 160, 1649, 62, 989, 185, 512, 990, 219, 12, 21, 27, 5, 424],
#  [40, 160, 1649, 62, 989, 185, 512, 990, 219, 12, 21, 27, 5, 424, 1],
#  [40, 160, 1649, 62, 989, 185, 512, 990, 219, 12, 21, 27, 5, 424, 1, 146],
#  [40, 160, 1649, 62, 989, 185, 512, 990, 219, 12, 21, 27, 5, 424, 1, 146, 6],
#  [40,
#   160,
#   1649,
#   62,
#   989,
#   185,
#   512,
#   990,
#   219,
#   12,
#   21,
#   27,
#   5,
#   424,
#   1,
#   146,
#   6,
#   2],
#  [40,
#   160,
#   1649,
#   62,
#   989,
#   185,
#   512,
#   990,
#   219,
#   12,
#   21,
#   27,
#   5,
#   424,
#   1,
#   146,
#   6,
#   2,
#   1650],
#  [40,
#   160,
#   1649,
#   62,
#   989,
#   185,
#   512,
#   990,
#   219,
#   12,
#   21,
#   27,
#   5,
#   424,
#   1,
#   146,
#   6,
#   2,
#   1650,
#   528],
#  [40,
#   160,
#   1649,
#   62,
#   989,
#   185,
#   512,
#   990,
#   219,
#   12,
#   21,
#   27,
#   5,
#   424,
#   1,
#   146,
#   6,
#   2,
#   1650,
#   528,
#   33],
#  [40,
#   160,
#   1649,
#   62,
#   989,
#   185,
#   512,
#   990,
#   219,
#   12,
#   21,
#   27,
#   5,
#   424,
#   1,
#   146,
#   6,
#   2,
#   1650,
#   528,
#   33,
#   682],
#  [40,
#   160,
#   1649,
#   62,
#   989,
#   185,
#   512,
#   990,
#   219,
#   12,
#   21,
#   27,
#   5,
#   424,
#   1,
#   146,
#   6,
#   2,
#   1650,
#   528,
#   33,
#   682,
#   167],
#  [40,
#   160,
#   1649,
#   62,
#   989,
#   185,
#   512,
#   990,
#   219,
#   12,
#   21,
#   27,
#   5,
#   424,
#   1,
#   146,
#   6,
#   2,
#   1650,
#   528,
#   33,
#   682,
#   167,
#   126],
#  [40,
#   160,
#   1649,
#   62,
#   989,
#   185,
#   512,
#   990,
#   219,
#   12,
#   21,
#   27,
#   5,
#   424,
#   1,
#   146,
#   6,
#   2,
#   1650,
#   528,
#   33,
#   682,
#   167,
#   126,
#   682],
#  [40,
#   160,
#   1649,
#   62,
#   989,
#   185,
#   512,
#   990,
#   219,
#   12,
#   21,
#   27,
#   5,
#   424,
#   1,
#   146,
#   6,
#   2,
#   1650,
#   528,
#   33,
#   682,
#   167,
#   126,
#   682,
#   544],
#  [7, 137],
#  [7, 137, 224],
#  [7, 137, 224, 72],
#  [7, 137, 224, 72, 376],
#  [7, 137, 224, 72, 376, 63],
#  [7, 137, 224, 72, 376, 63, 33],
#  [7, 137, 224, 72, 376, 63, 33, 203],
#  [7, 137, 224, 72, 376, 63, 33, 203, 991],
#  [7, 137, 224, 72, 376, 63, 33, 203, 991, 7],
#  [7, 137, 224, 72, 376, 63, 33, 203, 991, 7, 22],
#  [7, 137, 224, 72, 376, 63, 33, 203, 991, 7, 22, 243],
#  [7, 137, 224, 72, 376, 63, 33, 203, 991, 7, 22, 243, 21],
#  [7, 137, 224, 72, 376, 63, 33, 203, 991, 7, 22, 243, 21, 9],
#  [7, 137, 224, 72, 376, 63, 33, 203, 991, 7, 22, 243, 21, 9, 15],
#  [7, 137, 224, 72, 376, 63, 33, 203, 991, 7, 22, 243, 21, 9, 15, 1],
#  [7, 137, 224, 72, 376, 63, 33, 203, 991, 7, 22, 243, 21, 9, 15, 1, 683],
#  [7, 137, 224, 72, 376, 63, 33, 203, 991, 7, 22, 243, 21, 9, 15, 1, 683, 992],
#  [7,
#   137,
#   224,
#   72,
#   376,
#   63,
#   33,
#   203,
#   991,
#   7,
#   22,
#   243,
#   21,
#   9,
#   15,
#   1,
#   683,
#   992,
#   42],
#  [7,
#   137,
#   224,
#   72,
#   376,
#   63,
#   33,
#   203,
#   991,
#   7,
#   22,
#   243,
#   21,
#   9,
#   15,
#   1,
#   683,
#   992,
#   42,
#   9],
#  [7,
#   137,
#   224,
#   72,
#   376,
#   63,
#   33,
#   203,
#   991,
#   7,
#   22,
#   243,
#   21,
#   9,
#   15,
#   1,
#   683,
#   992,
#   42,
#   9,
#   15],
#  [7,
#   137,
#   224,
#   72,
#   376,
#   63,
#   33,
#   203,
#   991,
#   7,
#   22,
#   243,
#   21,
#   9,
#   15,
#   1,
#   683,
#   992,
#   42,
#   9,
#   15,
#   113],
#  [7,
#   137,
#   224,
#   72,
#   376,
#   63,
#   33,
#   203,
#   991,
#   7,
#   22,
#   243,
#   21,
#   9,
#   15,
#   1,
#   683,
#   992,
#   42,
#   9,
#   15,
#   113,
#   993],
#  [7,
#   137,
#   224,
#   72,
#   376,
#   63,
#   33,
#   203,
#   991,
#   7,
#   22,
#   243,
#   21,
#   9,
#   15,
#   1,
#   683,
#   992,
#   42,
#   9,
#   15,
#   113,
#   993,
#   1651],
#  [7,
#   137,
#   224,
#   72,
#   376,
#   63,
#   33,
#   203,
#   991,
#   7,
#   22,
#   243,
#   21,
#   9,
#   15,
#   1,
#   683,
#   992,
#   42,
#   9,
#   15,
#   113,
#   993,
#   1651,
#   57],
#  [7,
#   137,
#   224,
#   72,
#   376,
#   63,
#   33,
#   203,
#   991,
#   7,
#   22,
#   243,
#   21,
#   9,
#   15,
#   1,
#   683,
#   992,
#   42,
#   9,
#   15,
#   113,
#   993,
#   1651,
#   57,
#   112],
#  [7,
#   137,
#   224,
#   72,
#   376,
#   63,
#   33,
#   203,
#   991,
#   7,
#   22,
#   243,
#   21,
#   9,
#   15,
#   1,
#   683,
#   992,
#   42,
#   9,
#   15,
#   113,
#   993,
#   1651,
#   57,
#   112,
#   437],
#  [7,
#   137,
#   224,
#   72,
#   376,
#   63,
#   33,
#   203,
#   991,
#   7,
#   22,
#   243,
#   21,
#   9,
#   15,
#   1,
#   683,
#   992,
#   42,
#   9,
#   15,
#   113,
#   993,
#   1651,
#   57,
#   112,
#   437,
#   6],
#  [7,
#   137,
#   224,
#   72,
#   376,
#   63,
#   33,
#   203,
#   991,
#   7,
#   22,
#   243,
#   21,
#   9,
#   15,
#   1,
#   683,
#   992,
#   42,
#   9,
#   15,
#   113,
#   993,
#   1651,
#   57,
#   112,
#   437,
#   6,
#   357],
#  [41, 1],
#  [41, 1, 244],
#  [41, 1, 244, 1652],
#  [41, 1, 244, 1652, 116],
#  [41, 1, 244, 1652, 116, 245],
#  [41, 1, 244, 1652, 116, 245, 58],
#  [41, 1, 244, 1652, 116, 245, 58, 1],
#  [41, 1, 244, 1652, 116, 245, 58, 1, 127],
#  [41, 1, 244, 1652, 116, 245, 58, 1, 127, 7],
#  [41, 1, 244, 1652, 116, 245, 58, 1, 127, 7, 100],
#  [41, 1, 244, 1652, 116, 245, 58, 1, 127, 7, 100, 45],
#  [41, 1, 244, 1652, 116, 245, 58, 1, 127, 7, 100, 45, 277],
#  [41, 1, 244, 1652, 116, 245, 58, 1, 127, 7, 100, 45, 277, 18],
#  [41, 1, 244, 1652, 116, 245, 58, 1, 127, 7, 100, 45, 277, 18, 2],
#  [41, 1, 244, 1652, 116, 245, 58, 1, 127, 7, 100, 45, 277, 18, 2, 61],
#  [41, 1, 244, 1652, 116, 245, 58, 1, 127, 7, 100, 45, 277, 18, 2, 61, 49],
#  [41, 1, 244, 1652, 116, 245, 58, 1, 127, 7, 100, 45, 277, 18, 2, 61, 49, 438],
#  [41,
#   1,
#   244,
#   1652,
#   116,
#   245,
#   58,
#   1,
#   127,
#   7,
#   100,
#   45,
#   277,
#   18,
#   2,
#   61,
#   49,
#   438,
#   8],
#  [41,
#   1,
#   244,
#   1652,
#   116,
#   245,
#   58,
#   1,
#   127,
#   7,
#   100,
#   45,
#   277,
#   18,
#   2,
#   61,
#   49,
#   438,
#   8,
#   1653],
#  [3, 684],
#  [3, 684, 11],
#  [3, 684, 11, 43],
#  [3, 684, 11, 43, 994],
#  [3, 684, 11, 43, 994, 12],
#  [3, 684, 11, 43, 994, 12, 6],
#  [3, 684, 11, 43, 994, 12, 6, 1654],
#  [1, 685],
#  [1, 685, 1655],
#  [1, 685, 1655, 1656],
#  [1, 685, 1655, 1656, 184],
#  [1, 685, 1655, 1656, 184, 686],
#  [1, 685, 1655, 1656, 184, 686, 278],
#  [1, 685, 1655, 1656, 184, 686, 278, 204],
#  [1, 685, 1655, 1656, 184, 686, 278, 204, 148],
#  [1, 685, 1655, 1656, 184, 686, 278, 204, 148, 6],
#  [1, 685, 1655, 1656, 184, 686, 278, 204, 148, 6, 7],
#  [1, 685, 1655, 1656, 184, 686, 278, 204, 148, 6, 7, 5],
#  [1, 685, 1655, 1656, 184, 686, 278, 204, 148, 6, 7, 5, 84],
#  [1, 685, 1655, 1656, 184, 686, 278, 204, 148, 6, 7, 5, 84, 85],
#  [1, 685, 1655, 1656, 184, 686, 278, 204, 148, 6, 7, 5, 84, 85, 60],
#  [45, 47],
#  ...]

# %%
len(input_sequences)
# Out:
# 16612

# %%
max_len = max([len(x) for x in input_sequences])

# %%
max_len
# Out:
# 44

# %%
from tensorflow.keras.preprocessing.sequence import pad_sequences
padded_input_sequences = pad_sequences(input_sequences, maxlen = max_len, padding='pre')

# %%
padded_input_sequences
# Out:
# array([[   0,    0,    0, ...,    0,   11,   13],
#        [   0,    0,    0, ...,   11,   13,   46],
#        [   0,    0,    0, ...,   13,   46, 1529],
#        ...,
#        [   0,    0,    0, ...,    4, 3980,   35],
#        [   0,    0,    0, ..., 3980,   35, 3981],
#        [   0,    0,    0, ...,   35, 3981,  853]], dtype=int32)

# %% [markdown]
# **Model** **Building**

# %%
X = padded_input_sequences[:,:-1]
y = padded_input_sequences[:,-1]

# %%
X.shape
# Out:
# (16612, 43)

# %%
y.shape
# Out:
# (16612,)

# %%
from tensorflow.keras.utils import to_categorical
y = to_categorical(y,num_classes=15279)

# %%
y.shape
# Out:
# (16612, 15279)

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Embedding, LSTM, Dense

# %%
model = Sequential()
model.add(Embedding(input_dim=15279, output_dim=2000))
model.add(LSTM(500))
model.add(Dense(15279, activation='softmax'))

# %%
model.compile(loss='categorical_crossentropy', optimizer='adam',metrics=['accuracy'])

# %%
model.summary()
# Out:
# Model: "sequential_2"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  embedding_2 (Embedding)     (None, None, 2000)        30558000
#
#  lstm_2 (LSTM)               (None, 500)               5002000
#
#  dense_2 (Dense)             (None, 15279)             7654779
#
# =================================================================
# Total params: 43214779 (164.85 MB)
# Trainable params: 43214779 (164.85 MB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
model.fit(X,y,epochs=20)
# Out:
# Epoch 1/20
# 520/520 [==============================] - 38s 67ms/step - loss: 7.2991 - accuracy: 0.0455
# Epoch 2/20
# 520/520 [==============================] - 21s 41ms/step - loss: 6.1507 - accuracy: 0.0949
# Epoch 3/20
# 520/520 [==============================] - 19s 37ms/step - loss: 5.1915 - accuracy: 0.1489
# Epoch 4/20
# 520/520 [==============================] - 19s 37ms/step - loss: 4.0210 - accuracy: 0.2330
# Epoch 5/20
# 520/520 [==============================] - 19s 37ms/step - loss: 2.7799 - accuracy: 0.4239
# Epoch 6/20
# 520/520 [==============================] - 19s 37ms/step - loss: 1.7170 - accuracy: 0.6431
# Epoch 7/20
# 520/520 [==============================] - 19s 36ms/step - loss: 1.0073 - accuracy: 0.8059
# Epoch 8/20
# 520/520 [==============================] - 19s 37ms/step - loss: 0.6071 - accuracy: 0.8911
# Epoch 9/20
# 520/520 [==============================] - 19s 36ms/step - loss: 0.4205 - accuracy: 0.9183
# Epoch 10/20
# 520/520 [==============================] - 19s 36ms/step - loss: 0.3440 - accuracy: 0.9253
# Epoch 11/20
# 520/520 [==============================] - 19s 37ms/step - loss: 0.3151 - accuracy: 0.9272
# Epoch 12/20
# 520/520 [==============================] - 19s 36ms/step - loss: 0.2993 - accuracy: 0.9287
# Epoch 13/20
# 520/520 [==============================] - 19s 36ms/step - loss: 0.2865 - accuracy: 0.9293
# Epoch 14/20
# 520/520 [==============================] - 19s 37ms/step - loss: 0.2817 - accuracy: 0.9289
# Epoch 15/20
# 520/520 [==============================] - 19s 37ms/step - loss: 0.2776 - accuracy: 0.9303
# Epoch 16/20
# 520/520 [==============================] - 19s 36ms/step - loss: 0.2742 - accuracy: 0.9305
# Epoch 17/20
# 520/520 [==============================] - 19s 37ms/step - loss: 0.2702 - accuracy: 0.9296
# Epoch 18/20
# 520/520 [==============================] - 19s 36ms/step - loss: 0.2726 - accuracy: 0.9294
# Epoch 19/20
# 520/520 [==============================] - 19s 36ms/step - loss: 0.4275 - accuracy: 0.8998
# Epoch 20/20
# 520/520 [==============================] - 19s 36ms/step - loss: 0.3653 - accuracy: 0.9113

# %% [markdown]
# Prediction

# %%
text = "what do"
for i in range(10):
  # tokenize
  token_text = tokenizer.texts_to_sequences([text])[0]
  # padding
  padded_token_text = pad_sequences([token_text], maxlen=56, padding='pre')
  # predict
  pos = np.argmax(model.predict(padded_token_text))

  for word,index in tokenizer.word_index.items():
    if index == pos:
      text = text + " " + word
      print(text)
# Out:
# 1/1 [==============================] - 0s 20ms/step
# what do you
# 1/1 [==============================] - 0s 17ms/step
# what do you call
# 1/1 [==============================] - 0s 19ms/step
# what do you call a
# 1/1 [==============================] - 0s 17ms/step
# what do you call a man
# 1/1 [==============================] - 0s 18ms/step
# what do you call a man with
# 1/1 [==============================] - 0s 20ms/step
# what do you call a man with no
# 1/1 [==============================] - 0s 19ms/step
# what do you call a man with no arms
# 1/1 [==============================] - 0s 20ms/step
# what do you call a man with no arms or
# 1/1 [==============================] - 0s 21ms/step
# what do you call a man with no arms or legs
# 1/1 [==============================] - 0s 20ms/step
# what do you call a man with no arms or legs being
